# %%
from ctm_python_client.core.workflow import Workflow, WorkflowDefaults
from ctm_python_client.core.comm import Environment
from ctm_python_client.ext.viz import get_graph
from aapi.job import *
from aapi import *

workflow = Workflow(
    Environment.create_workbench(host='workbench')
)

# Define a SimpleFolder
sample_folder = SimpleFolder(
    object_name='MySimpleFolder',  # SimpleFolder uses 'object_name' instead of a separate name field
    controlm_server='controlm',
    order_method=SimpleFolder.OrderMethod.Manual,  # Correct enum reference for SimpleFolder
    site_standard='mysitestandard',
    business_fields=[{'Department': 'HR'}, {'Company': 'BMC'}]
)

workflow.add(sample_folder)

get_graph(workflow)

# %% [markdown]
# from ctm_python_client.core.comm import Environment
# from aapi import *
