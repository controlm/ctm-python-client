# %%
import time as t
from ctm_python_client.core.workflow import Workflow, WorkflowDefaults
from ctm_python_client.core.comm import Environment, EnvironmentMode
from aapi import *

workflow1 = Workflow(Environment.create_workbench('workbench'), WorkflowDefaults(run_as='workbench'))

workflow1.clear_all()
run_as_dummy = True

databricksLoad = JobDatabricks(
    'LoadForecasts',
    connection_profile='DATABRICKS',
    databricks_job_id='991955986358417',
    parameters='"params":{}',
    idempotency_token = 'tokeni_%%ORDERID',
    run_as_dummy= run_as_dummy
)

terraform_scale_databricks = JobTerraform(
    'TerraformScale',
    connection_profile='TERRAFORM',
    action='Run Workspace',
    workspace_name='dealership-demo',
    run_name= "demorun%%ORDERID",
    variables = [{"min_workers":"4"},{"max_workers":"10"}],
    run_as_dummy= run_as_dummy
)

ExtractInventoryHistory = JobDatabricks(
    'ExtractInventoryHistory',
    connection_profile='DATABRICKS',
    databricks_job_id='658383437534753',
    parameters='"params":{}',
    idempotency_token = 'token_%%ORDERID',
    run_as_dummy= run_as_dummy
)

web_service_job = JobWebServices(
    object_name='WeatherService',
    run_as_dummy=run_as_dummy,
    connection_profile='WeatherAPI',
    service='ForecastService',
    operation='GetWeather',
    request_type=JobWebServices.RequestType.FreeText,
    soap_request=['<SOAP-ENV>Request</SOAP-ENV>']
)

query_job = JobDatabaseSQLScript(
    object_name='QueryWeather',
    run_as_dummy=run_as_dummy,
    sql_script='UPDATE weather SET forecast="sunny" WHERE city="Seattle"',
    connection_profile='db_profile'
)

sagemaker_job = JobAwsSageMaker(
    f'InventoryForecastModel',
    connection_profile= 'SAGEMAKER',
    pipeline_name= 'InferencePipeline',
    idempotency_token= 'Token_ControlM_for_SageMaker%%ORDERID',
    add_parameters= 'checked',
    parameters= '{"Name":"input_file", "Value": "file"}',
    run_as_dummy= run_as_dummy,
    retry_pipeline_execution='unchecked',
    rerun_limit= Job.RerunLimit(times='5')
)

tableau_refresh = JobTableau(
    'TableauRefresh',
    connection_profile='TABLEAU',
    action="Refresh Datasource",
    datasource_name="inventory_forecast",
    run_as_dummy=run_as_dummy
)

folder = Folder('Folder_Sanity_Integration_Factory',
                controlm_server='workbench',
                job_list=[databricksLoad, terraform_scale_databricks, ExtractInventoryHistory, databricksLoad, web_service_job, query_job, sagemaker_job, tableau_refresh])


print(folder.dumps_aapi(indent=2))
workflow1.add(folder)

workflow1.build()
workflow1.deploy()
run = workflow1.run()
jobs = Workflow.get_jobs_list_of_folders(Environment.create_workbench('workbench'),server="workbench", folder="Folder_Sanity_Integration_Factory")

jobs1 = workflow1.get_jobs_draft_with_workflow_instance(server="workbench", folder="Folder_Sanity_Integration_Factory")
print(jobs)
# Out:
# [DEBUG] Initializing shared Converter instance.
# [DEBUG] Discovering all @attrs classes under aapi...
# [DEBUG] Registering structure hooks for discovered @attrs classes...
# [DEBUG] Registering structure hooks for the following classes: ['JobVMwarePowerOff', 'ConnectionProfileAwsBatch', 'ActionSetToOK', 'JobFileWatcher', 'JobAWS', 'RunningJobs', 'ConnectionProfileIBMDataStageLinux', 'JobVMwareConfigurationDeployTemplate', 'JobCommunicationSuite', 'JobAzure', 'EndpointDestSftp', 'FolderClientData', 'JobOS400FullVirtualTerminal', 'JobSAPR3COPY', 'JobHadoopHDFSCommands', 'JobAWSBatch', 'ConnectionProfileMicrosoftPowerBISP', 'ConnectionProfileSnowflakeIdP', 'JobOS400Full', 'ConnectionProfileFileTransferLocal', 'ConnectionProfileAzureSynapse', 'ConnectionProfileAirbyte', 'ConnectionProfileFileTransferAzure', 'SiteStandard', 'ConnectionProfileInformaticaCS', 'JobAwsGlue', 'JobVMwarePower', 'JobAirbyte', 'JobAzureFunction', 'Tag', 'JobGCPDataflow', 'TagFolder', 'ConnectionProfileAwsCloudFormation', 'Notify', 'JobDummy', 'JobOS400', 'EventOutAdd', 'NotifyDoesNotStart', 'JobAwsStepFunctions', 'JobAwsAthena', 'JobVMware', 'JobAzureSynapse', 'JobAzureLogicApps', 'WorkloadPolicy', 'ConnectionProfileDatabaseMSSqlSSIS', 'JobOS400VirtualTerminal', 'ConnectionProfileGCPFunctions', 'ConnectionProfileAwsMainframeModernization', 'JobGCPDataplex', 'EventOut', 'JobVMwareConfiguration', 'ConnectionProfileWebServices', 'ConnectionProfileAwsDataPipeline', 'JobHadoopHDFSFileWatcher', 'ConnectionProfileAirflowStandalone', 'ConnectionProfileCircleCI', 'JobVMwareConfigurationReconfigureVirtualMachine', 'IfNumberOfFailures', 'ConnectionProfileAwsBackup', 'NotifyLateCyclicSubmit', 'JobAWSLambda', 'ConnectionProfileDatabaseOracleServiceName', 'ConnectionProfileApacheAirflow', 'ConnectionProfileBoomiAtomsphere', 'JobAzureDatabricks', 'StepRange', 'JobAwsBatch', 'JobSAPDataArchivingWrite', 'AIConnectionProfile', 'JobAwsMWAA', 'JobAwsBackup', 'JobIBMDataStageLinux', 'ResourcePool', 'ConnectionProfileAstronomer', 'JobUIPath', 'ConnectionProfileAirflowGoogleComposer', 'CalendarRegular', 'JobOS400FullCommandLine', 'ConnectionProfileAwsAthena', 'JobSLAManagement', 'ConnectionProfileWebServicesREST', 'JobAzureMachineLearning', 'JobAwsAppRunner', 'JobGCPDeploymentManager', 'ActionCaptureOutput', 'JobAzureBatchAccounts', 'IfZOSSpecificRangeName', 'NotifyDoesNotEnd', 'ConnectionProfileFileTransferAzureAdClientSecret', 'JobSAPR3TriggerSapEvent', 'JobSAP', 'ActionRemedy', 'JobSAPR3WatchSapEvent', 'JobSAPR3BatchInputSession', 'ConnectionProfileDBT', 'ConnectionProfileTalendDataManagement', 'ConnectionProfileAwsStepFunctions', 'JobBoomiAtomsphere', 'Date', 'ConnectionProfileDatabaseOracle', 'DeleteEvents', 'JobAwsEMR', 'ActionSet', 'EventOutDelete', 'ConnectionProfileDatabase', 'ActionOutput', 'JobVMwarePowerSuspend', 'JobHadoopHive', 'ConnectionProfile', 'ConnectionProfileFileTransferS3Amazon', 'JobAwsLambda', 'JobDatabase', 'IfZOSOutputPattern', 'JobSAPBWInfoPackage', 'Endpoint', 'JobDatabaseMSSQLAgentJob', 'EndpointDest', 'Calendar', 'SiteStandardPossibleValue', 'JobSAPR3PredefinedSapJob', 'JobAwsDataPipeline', 'ConnectionProfileAzure', 'JobHadoopSqoop', 'JobAzureDataFactory', 'PossibleOptions', 'EndpointSrcSftp', 'JobTandemCommand', 'JobAzureHDInsight', 'Config', 'JobNetBackup', 'JobHadoopSpark', 'ConnectionProfileDatabaseMSSql', 'CalendarRuleBasedCalendar', 'ConditionOutAdd', 'ConnectionProfileSnowflake', 'FolderJobBaseSmart', 'ConnectionProfileAlteryxTrifacta', 'IfBase', 'JobJenkins', 'JobTandem', 'ConnectionProfileAzureMachineLearning', 'JobOS400MultipleCommands', 'IfZOS', 'JobOS400ExternalJob', 'EventIn', 'JobDatabaseStoredProcedure', 'JobTandemTACLScript', 'JobAwsDynamoDB', 'ConnectionProfileTerraform', 'ConnectionProfileWebServicesSOAP', 'IfCompletionStatus', 'ConnectionProfileGCPDataplex', 'ActionControlMAnalyzerRule', 'WorkloadFlat', 'ConnectionProfileGCPDataFusion', 'ConnectionProfileAwsQuickSight', 'WaitForEvents', 'ConnectionProfileFileTransferS3', 'ConnectionProfileAzureServiceBus', 'ConnectionProfileMicroFocusLinux', 'JobAzureLogicApps', 'JobDatabaseSQLScript', 'JobTandemEmbeddedTACLScript', 'EndpointDestFtps', 'JobAstronomer ...
# [DEBUG] Building job type map.
# [WARN] Could not resolve _type for AIJob: AIJob.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobAWSBatch: JobAWSBatch.__init__() missing 3 required positional arguments: 'job_name', 'job_definition', and 'job_queue'
# [WARN] Could not resolve _type for JobAWSLambda: JobAWSLambda.__init__() missing 1 required positional argument: 'function_name'
# [WARN] Could not resolve _type for JobAirflow: JobAirflow.__init__() missing 2 required positional arguments: 'connection_profile' and 'dag_id'
# [WARN] Could not resolve _type for JobAzureBatchAccount: JobAzureBatchAccount.__init__() missing 2 required positional arguments: 'job_id' and 'command_line'
# [WARN] Could not resolve _type for JobAzureFunction: JobAzureFunction.__init__() missing 2 required positional arguments: 'function' and 'function_app'
# [WARN] Could not resolve _type for JobCommand: JobCommand.__init__() missing 1 required positional argument: 'command'
# [WARN] Could not resolve _type for JobDatabaseEmbeddedQuery: JobDatabaseEmbeddedQuery.__init__() missing 1 required positional argument: 'query'
# [WARN] Could not resolve _type for JobDatabaseMSSQLAgentJob: JobDatabaseMSSQLAgentJob.__init__() missing 1 required positional argument: 'job_name'
# [WARN] Could not resolve _type for JobDatabaseMSSQL_SSIS: JobDatabaseMSSQL_SSIS.__init__() missing 2 required positional arguments: 'package_source' and 'package_name'
# [WARN] Could not resolve _type for JobDatabaseStoredProcedure: JobDatabaseStoredProcedure.__init__() missing 2 required positional arguments: 'schema' and 'stored_procedure'
# [WARN] Could not resolve _type for JobEmbeddedScript: JobEmbeddedScript.__init__() missing 2 required positional arguments: 'script' and 'file_name'
# [WARN] Could not resolve _type for JobFileWatcher: JobFileWatcher.__init__() missing 1 required positional argument: 'path'
# [WARN] Could not resolve _type for JobFileWatcherCreate: JobFileWatcherCreate.__init__() missing 1 required positional argument: 'path'
# [WARN] Could not resolve _type for JobFileWatcherDelete: JobFileWatcherDelete.__init__() missing 1 required positional argument: 'path'
# [WARN] Could not resolve _type for JobHadoopDistCp: JobHadoopDistCp.__init__() missing 1 required positional argument: 'target_path'
# [WARN] Could not resolve _type for JobHadoopHive: JobHadoopHive.__init__() missing 1 required positional argument: 'hive_script'
# [WARN] Could not resolve _type for JobHadoopMapReduce: JobHadoopMapReduce.__init__() missing 1 required positional argument: 'program_jar'
# [WARN] Could not resolve _type for JobHadoopMapredStreaming: JobHadoopMapredStreaming.__init__() missing 1 required positional argument: 'input_path'
# [WARN] Could not resolve _type for JobHadoopPig: JobHadoopPig.__init__() missing 1 required positional argument: 'pig_script'
# [WARN] Could not resolve _type for JobHadoopSparkPython: JobHadoopSparkPython.__init__() missing 1 required positional argument: 'spark_script'
# [WARN] Could not resolve _type for JobHadoopSparkScalaJava: JobHadoopSparkScalaJava.__init__() missing 2 required positional arguments: 'program_jar' and 'main_class'
# [WARN] Could not resolve _type for JobHadoopTajoInputFile: JobHadoopTajoInputFile.__init__() missing 1 required positional argument: 'full_file_path'
# [WARN] Could not resolve _type for JobHadoopTajoQuery: JobHadoopTajoQuery.__init__() missing 1 required positional argument: 'open_query'
# [WARN] Could not resolve _type for JobIBMCognos: JobIBMCognos.__init__() missing 2 required positional arguments: 'connection_profile' and 'jobs'
# [WARN] Could not resolve _type for JobIBMDataStage: JobIBMDataStage.__init__() missing 3 required positional arguments: 'connection_profile', 'project', and 'data_stage_job'
# [WARN] Could not resolve _type for JobInformatica: JobInformatica.__init__() missing 5 required positional arguments: 'connection_profile', 'repository_folder', 'workflow', 'workflow_execution_mode', and 'workflow_restart_mode'
# [WARN] Could not resolve _type for JobJava: JobJava.__init__() missing 3 required positional arguments: 'connection_profile', 'object', and 'method'
# [WARN] Could not resolve _type for JobOEBS: JobOEBS.__init__() missing 3 required positional arguments: 'connection_profile', 'user_name', and 'responsibility'
# [WARN] Could not resolve _type for JobOS400FullCommandLine: JobOS400FullCommandLine.__init__() missing 1 required positional argument: 'command_line'
# [WARN] Could not resolve _type for JobOS400FullDescriptionJob: JobOS400FullDescriptionJob.__init__() missing 2 required positional arguments: 'library' and 'description'
# [WARN] Could not resolve _type for JobOS400FullSubSystem: JobOS400FullSubSystem.__init__() missing 2 required positional arguments: 'library' and 'sub_system'
# [WARN] Could not resolve _type for JobOS400Program: JobOS400Program.__init__() missing 2 required positional arguments: 'program' and 'library'
# [WARN] Could not resolve _type for JobSAPDataArchivingDelete: JobSAPDataArchivingDelete.__init__() missing 3 required positional arguments: 'job_name', 'archiving_object', and 'session_number'
# [WARN] Could not resolve _type for JobSAPDataArchivingStore: JobSAPDataArchivingStore.__init__() missing 3 required positional arguments: 'job_name', 'archiving_object', and 'session_number'
# [WARN] Could not resolve _type for JobSAPDataArchivingWrite: JobSAPDataArchivingWrite.__init__() missing 2 required positional arguments: 'job_name' and 'archiving_object'
# [WARN] Could not resolve _type for JobSAPR3TriggerSapEvent: JobSAPR3TriggerSapEvent.__init__() missing 1 required positional argument: 'event_id'
# [WARN] Could not resolve _type for JobSAPR3WatchSapEvent: JobSAPR3WatchSapEvent.__init__() missing 1 required positional argument: 'event_id'
# [WARN] Could not resolve _type for JobSLAManagement: JobSLAManagement.__init__() missing 1 required positional argument: 'service_name'
# [WARN] Could not resolve _type for JobScript: JobScript.__init__() missing 2 required positional arguments: 'file_name' and 'file_path'
# [WARN] Could not resolve _type for JobTandem: JobTandem.__init__() missing 1 required positional argument: 'job_owner'
# [WARN] Could not resolve _type for JobTandemCommand: JobTandemCommand.__init__() missing 2 required positional arguments: 'job_owner' and 'command_line'
# [WARN] Could not resolve _type for JobTandemEmbeddedTACLScript: JobTandemEmbeddedTACLScript.__init__() missing 3 required positional arguments: 'job_owner', 'tacl_script', and 'script'
# [WARN] Could not resolve _type for JobTandemExternalProcess: JobTandemExternalProcess.__init__() missing 1 required positional argument: 'job_owner'
# [WARN] Could not resolve _type for JobTandemProgram: JobTandemProgram.__init__() missing 3 required positional arguments: 'job_owner', 'program', and 'volume'
# [WARN] Could not resolve _type for JobTandemTACLScript: JobTandemTACLScript.__init__() missing 3 required positional arguments: 'job_owner', 'tacl_script', and 'volume'
# [WARN] Could not resolve _type for JobVMware: JobVMware.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareConfiguration: JobVMwareConfiguration.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareConfigurationCloneVirtualMachine: JobVMwareConfigurationCloneVirtualMachine.__init__() missing 4 required positional arguments: 'connection_profile', 'new_virtual_machine_name', 'target_host', and 'datastore'
# [WARN] Could not resolve _type for JobVMwareConfigurationDeployTemplate: JobVMwareConfigurationDeployTemplate.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareConfigurationMigrateVirtualMachine: JobVMwareConfigurationMigrateVirtualMachine.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareConfigurationReconfigureVirtualMachine: JobVMwareConfigurationReconfigureVirtualMachine.__init__() missing 2 required positional arguments: 'connection_profile' and 'number_of_cpus'
# [WARN] Could not resolve _type for JobVMwarePower: JobVMwarePower.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwarePowerOff: JobVMwarePowerOff.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwarePowerOn: JobVMwarePowerOn.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwarePowerReboot: JobVMwarePowerReboot.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwarePowerReset: JobVMwarePowerReset.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwarePowerShutdown: JobVMwarePowerShutdown.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwarePowerStandby: JobVMwarePowerStandby.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwarePowerSuspend: JobVMwarePowerSuspend.__init__() missing 2 required positional arguments: 'connection_profile' and 'virtual_machine_name'
# [WARN] Could not resolve _type for JobVMwareSnapshot: JobVMwareSnapshot.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareSnapshotRemove: JobVMwareSnapshotRemove.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareSnapshotRemoveAll: JobVMwareSnapshotRemoveAll.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareSnapshotRevert: JobVMwareSnapshotRevert.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareSnapshotRevertToCurrent: JobVMwareSnapshotRevertToCurrent.__init__() missing 1 required positional argument: 'connection_profile'
# [WARN] Could not resolve _type for JobVMwareSnapshotTake: JobVMwareSnapshotTake.__init__() missing 2 required positional arguments: 'connection_profile' and 'snapshot_name'
# {
#   "Type": "Folder",
#   "ControlmServer": "workbench",
#   "Jobs": [
#     {
#       "Type": "Job:Databricks",
#       "RunAsDummy": true,
#       "ConnectionProfile": "DATABRICKS",
#       "Databricks Job ID": "991955986358417",
#       "Parameters": "\"params\":{}",
#       "Idempotency Token": "tokeni_%%ORDERID"
#     },
#     {
#       "Type": "Job:Terraform",
#       "Variables": [
#         {
#           "min_workers": "4"
#         },
#         {
#           "max_workers": "10"
#         }
#       ],
#       "RunAsDummy": true,
#       "ConnectionProfile": "TERRAFORM",
#       "Action": "Run Workspace",
#       "Workspace Name": "dealership-demo",
#       "Run Name": "demorun%%ORDERID"
#     },
#     {
#       "Type": "Job:Databricks",
#       "RunAsDummy": true,
#       "ConnectionProfile": "DATABRICKS",
#       "Databricks Job ID": "658383437534753",
#       "Parameters": "\"params\":{}",
#       "Idempotency Token": "token_%%ORDERID"
#     },
#     {
#       "Type": "Job:Databricks",
#       "RunAsDummy": true,
#       "ConnectionProfile": "DATABRICKS",
#       "Databricks Job ID": "991955986358417",
#       "Parameters": "\"params\":{}",
#       "Idempotency Token": "tokeni_%%ORDERID"
#     },
#     {
#       "Type": "Job:WebServices",
#       "RunAsDummy": true,
#       "ConnectionProfile": "WeatherAPI",
#       "Service": "ForecastService",
#       "Operation": "GetWeather",
#       "RequestType": "FreeText",
#       "SoapRequest": [
#         "<SOAP-ENV>Request</SOAP-ENV>"
#       ]
#     },
#     {
#       "Type": "Job:Database:SQLScript",
#       "RunAsDummy": true,
#       "ConnectionProfile": "db_profile",
#       "SQLScript": "UPDATE weather SET forecast=\"sunny\" WHERE city=\"Seattle\""
#     },
#     {
#       "Type": "Job:AWS SageMaker",
#       "RerunLimit": {
#         "Times": "5"
#       },
#       "RunAsDummy": true,
#       "ConnectionProfile": "SAGEMAKER",
#       "Pipeline Name": "InferencePipeline",
#       "Idempotency Token": "Token_ControlM_for_SageMaker%%ORDERID",
#       "Add Parameters": "checked",
#       "Parameters": "{\"Name\":\"input_file\", \"Value\": \"file\"}",
#       "Retry Pipeline Execution": "unchecked"
#     },
#     {
#       "Type": "Job:Tableau",
#       "RunAsDummy": true,
#       "ConnectionProfile": "TABLEAU",
#       "Action": "Refresh Datasource",
#       "Datasource Name": "inventory_forecast"
#     }
#   ]
# }
#
# [DEBUG] Deserializing class: Folder
# [DEBUG] Raw data: {'Type': 'Folder', 'ControlmServer': 'workbench', 'RunAs': 'workbench', 'Jobs': [{'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}, {'Type': 'Job:Terraform', 'ConnectionProfile': 'TERRAFORM', 'Action': 'Run Workspace', 'Workspace Name': 'dealership-demo', 'Run Name': 'demorun%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'Name': 'Jobs2', 'object_name': 'Jobs2'}, {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '658383437534753', 'Parameters': '"params":{}', 'Idempotency Token': 'token_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs3', 'object_name': 'Jobs3'}, {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs4', 'object_name': 'Jobs4'}, {'Type': 'Job:WebServices', 'ConnectionProfile': 'WeatherAPI', 'Service': 'ForecastService', 'Operation': 'GetWeather', 'RequestType': 'FreeText', 'RunAsDummy': True, 'RunAs': 'WeatherAPI', 'SoapRequest': ['<SOAP-ENV>Request</SOAP-ENV>'], 'Name': 'Jobs5', 'object_name': 'Jobs5'}, {'Type': 'Job:Database:SQLScript', 'ConnectionProfile': 'db_profile', 'SQLScript': 'UPDATE weather SET forecast="sunny" WHERE city="Seattle"', 'RunAsDummy': True, 'RunAs': 'db_profile', 'Name': 'Jobs6', 'object_name': 'Jobs6'}, {'Type': 'Job:AWS SageMaker', 'ConnectionProfile': 'SAGEMAKER', 'Pipeline Name': 'InferencePipeline', 'Idempotency Token': 'Token_ControlM_for_SageMaker%%ORDERID', 'Add Parameters': 'checked', 'Parameters': '{"Name":"input_file", "Value": "file"}', 'Retry Pipeline Execution': 'unchecked', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs7', 'RerunLimit': {'Times': '5'}, 'object_name': 'Jobs7'}, {'Type': 'Job:Tableau', 'ConnectionProfile': 'TABLEAU', 'Action': 'Refresh Datasource', 'Datasource Name': 'inventory_forecast', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs8', 'object_name': 'Jobs8'}], 'object_name': 'Folder_Sanity_Integration_Factory'}
# [DEBUG] Field map: {'ControlmServer': 'controlm_server', 'OrderMethod': 'order_method', 'FolderLibrary': 'folder_library', 'SiteStandard': 'site_standard', 'BusinessFields': 'business_fields', 'Jobs': 'job_list', 'folder_client_data_list': 'folder_client_data_list', 'Type': '_type', 'object_name': 'object_name', 'Priority': 'priority', 'Application': 'application', 'CreatedBy': 'created_by', 'Confirm': 'confirm', 'DaysKeepActive': 'days_keep_active', 'Description': 'description', 'DaysKeepActiveIfNotOk': 'days_keep_active_if_not_ok', 'ActiveRetentionPolicy': 'active_retention_policy', 'RunAs': 'run_as', 'DocumentationFile': 'documentation_file', 'DocumentationUrl': 'documentation_url', 'MemberLibrary': 'member_library', 'StatisticsCalendar': 'statistics_calendar', 'SAC': 'sac', 'MustEnd': 'must_end', 'RerunLimit': 'rerun_limit', 'Rerun': 'rerun', 'RerunIntervals': 'rerun_intervals', 'RerunSpecificTimes': 'rerun_specific_times', 'SubApplication': 'sub_application', 'TimeZone': 'time_zone', 'Variables': 'variables', 'AdjustEvents': 'adjust_events', 'When': 'when', 'if_list': 'if_list', 'event_list': 'event_list', 'wait_for_events': 'wait_for_events', 'events_to_add': 'events_to_add', 'events_to_delete': 'events_to_delete', 'notify_list': 'notify_list', 'resource_lock_list': 'resource_lock_list', 'sub_folder_list': 'sub_folder_list', 'wait_for_events_list': 'wait_for_events_list', 'add_events_list': 'add_events_list', 'delete_events_list': 'delete_events_list'}
# [DEBUG] Processing field 'controlm_server' (from key 'ControlmServer'), type=<class 'str'>, value=workbench
# [DEBUG] Key 'OrderMethod' not in input data. Skipping.
# [DEBUG] Key 'FolderLibrary' not in input data. Skipping.
# [DEBUG] Key 'SiteStandard' not in input data. Skipping.
# [DEBUG] Key 'BusinessFields' not in input data. Skipping.
# [DEBUG] Processing field 'job_list' (from key 'Jobs'), type=typing.List[aapi.job.Job], value=[{'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}, {'Type': 'Job:Terraform', 'ConnectionProfile': 'TERRAFORM', 'Action': 'Run Workspace', 'Workspace Name': 'dealership-demo', 'Run Name': 'demorun%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'Name': 'Jobs2', 'object_name': 'Jobs2'}, {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '658383437534753', 'Parameters': '"params":{}', 'Idempotency Token': 'token_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs3', 'object_name': 'Jobs3'}, {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs4', 'object_name': 'Jobs4'}, {'Type': 'Job:WebServices', 'ConnectionProfile': 'WeatherAPI', 'Service': 'ForecastService', 'Operation': 'GetWeather', 'RequestType': 'FreeText', 'RunAsDummy': True, 'RunAs': 'WeatherAPI', 'SoapRequest': ['<SOAP-ENV>Request</SOAP-ENV>'], 'Name': 'Jobs5', 'object_name': 'Jobs5'}, {'Type': 'Job:Database:SQLScript', 'ConnectionProfile': 'db_profile', 'SQLScript': 'UPDATE weather SET forecast="sunny" WHERE city="Seattle"', 'RunAsDummy': True, 'RunAs': 'db_profile', 'Name': 'Jobs6', 'object_name': 'Jobs6'}, {'Type': 'Job:AWS SageMaker', 'ConnectionProfile': 'SAGEMAKER', 'Pipeline Name': 'InferencePipeline', 'Idempotency Token': 'Token_ControlM_for_SageMaker%%ORDERID', 'Add Parameters': 'checked', 'Parameters': '{"Name":"input_file", "Value": "file"}', 'Retry Pipeline Execution': 'unchecked', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs7', 'RerunLimit': {'Times': '5'}, 'object_name': 'Jobs7'}, {'Type': 'Job:Tableau', 'ConnectionProfile': 'TABLEAU', 'Action': 'Refresh Datasource', 'Datasource Name': 'inventory_forecast', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs8', 'object_name': 'Jobs8'}]
# [DEBUG] Structuring list field 'job_list' with item type '<class 'aapi.job.Job'>'
# [DEBUG] extracted Type hint: Job:Databricks
# [DEBUG] resolved Type 'Job:Databricks' to class JobDatabricks
#
# [DEBUG] Deserializing class: JobDatabricks
# [DEBUG] Raw data: {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}
# [DEBUG] Field map: {'PathElement': 'path_element', 'FileName': 'file_name', 'FilePath': 'file_path', 'Host': 'host', 'Application': 'application', 'Priority': 'priority', 'Critical': 'critical', 'Confirm': 'confirm', 'DaysKeepActive': 'days_keep_active', 'Description': 'description', 'DocumentationFile': 'documentation_file', 'DocumentationUrl': 'documentation_url', 'RerunLimit': 'rerun_limit', 'Rerun': 'rerun', 'RerunIntervals': 'rerun_intervals', 'RerunSpecificTimes': 'rerun_specific_times', 'PostCommand': 'post_command', 'PreCommand': 'pre_command', 'RunAs': 'run_as', 'SubApplication': 'sub_application', 'TimeZone': 'time_zone', 'Variables': 'variables', 'When': 'when', 'RunOnAllAgentsInGroup': 'run_on_all_agents_in_group', 'Output': 'output', 'RunAsDummy': 'run_as_dummy', 'RetroactiveOrder': 'retroactive_order', 'EndFolder': 'end_folder', 'CreatedBy': 'created_by', 'if_list': 'if_list', 'event_list': 'event_list', 'resource_list': 'resource_list', 'wait_for_events': 'wait_for_events', 'events_to_add': 'events_to_add', 'events_to_delete': 'events_to_delete', 'notify_list': 'notify_list', 'job_tag_list': 'job_tag_list', 'action_capture_output_list': 'action_capture_output_list', 'wait_for_events_list': 'wait_for_events_list', 'add_events_list': 'add_events_list', 'delete_events_list': 'delete_events_list', 'condition_list': 'condition_list', 'Type': '_type', 'object_name': 'object_name', 'ConnectionProfile': 'connection_profile', 'Databricks Job ID': 'databricks_job_id', 'Parameters': 'parameters', 'Idempotency Token': 'idempotency_token', 'Status Polling Frequency': 'status_polling_frequency', 'Failure Tolerance': 'failure_tolerance'}
# [DEBUG] Key 'PathElement' not in input data. Skipping.
# [DEBUG] Key 'FileName' not in input data. Skipping.
# [DEBUG] Key 'FilePath' not in input data. Skipping.
# [DEBUG] Key 'Host' not in input data. Skipping.
# [DEBUG] Key 'Application' not in input data. Skipping.
# [DEBUG] Key 'Priority' not in input data. Skipping.
# [DEBUG] Key 'Critical' not in input data. Skipping.
# [DEBUG] Key 'Confirm' not in input data. Skipping.
# [DEBUG] Key 'DaysKeepActive' not in input data. Skipping.
# [DEBUG] Key 'Description' not in input data. Skipping.
# [DEBUG] Key 'DocumentationFile' not in input data. Skipping.
# [DEBUG] Key 'DocumentationUrl' not in input data. Skipping.
# [DEBUG] Key 'RerunLimit' not in input data. Skipping.
# [DEBUG] Key 'Rerun' not in input data. Skipping.
# [DEBUG] Key 'RerunIntervals' not in input data. Skipping.
# [DEBUG] Key 'RerunSpecificTimes' not in input data. Skipping.
# [DEBUG] Key 'PostCommand' not in input data. Skipping.
# [DEBUG] Key 'PreCommand' not in input data. Skipping.
# [DEBUG] Processing field 'run_as' (from key 'RunAs'), type=<class 'str'>, value=workbench
# [DEBUG] Key 'SubApplication' not in input data. Skipping.
# [DEBUG] Key 'TimeZone' not in input data. Skipping.
# [DEBUG] Key 'Variables' not in input data. Skipping.
# [DEBUG] Key 'When' not in input data. Skipping.
# [DEBUG] Key 'RunOnAllAgentsInGroup' not in input data. Skipping.
# [DEBUG] Key 'Output' not in input data. Skipping.
# [DEBUG] Processing field 'run_as_dummy' (from key 'RunAsDummy'), type=<class 'bool'>, value=True
# [DEBUG] Key 'RetroactiveOrder' not in input data. Skipping.
# [DEBUG] Key 'EndFolder' not in input data. Skipping.
# [DEBUG] Key 'CreatedBy' not in input data. Skipping.
# [DEBUG] Key 'if_list' not in input data. Skipping.
# [DEBUG] Key 'event_list' not in input data. Skipping.
# [DEBUG] Key 'resource_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events' not in input data. Skipping.
# [DEBUG] Key 'events_to_add' not in input data. Skipping.
# [DEBUG] Key 'events_to_delete' not in input data. Skipping.
# [DEBUG] Key 'notify_list' not in input data. Skipping.
# [DEBUG] Key 'job_tag_list' not in input data. Skipping.
# [DEBUG] Key 'action_capture_output_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events_list' not in input data. Skipping.
# [DEBUG] Key 'add_events_list' not in input data. Skipping.
# [DEBUG] Key 'delete_events_list' not in input data. Skipping.
# [DEBUG] Key 'condition_list' not in input data. Skipping.
# [DEBUG] Field '_type' not in init fields. Skipping.
# [DEBUG] Processing field 'object_name' (from key 'object_name'), type=<class 'str'>, value=Jobs1
# [DEBUG] Processing field 'connection_profile' (from key 'ConnectionProfile'), type=<class 'str'>, value=DATABRICKS
# [DEBUG] Processing field 'databricks_job_id' (from key 'Databricks Job ID'), type=<class 'str'>, value=991955986358417
# [DEBUG] Processing field 'parameters' (from key 'Parameters'), type=<class 'str'>, value="params":{}
# [DEBUG] Processing field 'idempotency_token' (from key 'Idempotency Token'), type=<class 'str'>, value=tokeni_%%ORDERID
# [DEBUG] Key 'Status Polling Frequency' not in input data. Skipping.
# [DEBUG] Key 'Failure Tolerance' not in input data. Skipping.
# [DEBUG] Final kwargs for JobDatabricks: {'run_as': 'workbench', 'run_as_dummy': True, 'object_name': 'Jobs1', 'connection_profile': 'DATABRICKS', 'databricks_job_id': '991955986358417', 'parameters': '"params":{}', 'idempotency_token': 'tokeni_%%ORDERID'}
# [DEBUG] extracted Type hint: Job:Terraform
# [DEBUG] resolved Type 'Job:Terraform' to class JobTerraform
#
# [DEBUG] Deserializing class: JobTerraform
# [DEBUG] Raw data: {'Type': 'Job:Terraform', 'ConnectionProfile': 'TERRAFORM', 'Action': 'Run Workspace', 'Workspace Name': 'dealership-demo', 'Run Name': 'demorun%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'Name': 'Jobs2', 'object_name': 'Jobs2'}
# [DEBUG] Field map: {'PathElement': 'path_element', 'FileName': 'file_name', 'FilePath': 'file_path', 'Host': 'host', 'Application': 'application', 'Priority': 'priority', 'Critical': 'critical', 'Confirm': 'confirm', 'DaysKeepActive': 'days_keep_active', 'Description': 'description', 'DocumentationFile': 'documentation_file', 'DocumentationUrl': 'documentation_url', 'RerunLimit': 'rerun_limit', 'Rerun': 'rerun', 'RerunIntervals': 'rerun_intervals', 'RerunSpecificTimes': 'rerun_specific_times', 'PostCommand': 'post_command', 'PreCommand': 'pre_command', 'RunAs': 'run_as', 'SubApplication': 'sub_application', 'TimeZone': 'time_zone', 'Variables': 'variables', 'When': 'when', 'RunOnAllAgentsInGroup': 'run_on_all_agents_in_group', 'Output': 'output', 'RunAsDummy': 'run_as_dummy', 'RetroactiveOrder': 'retroactive_order', 'EndFolder': 'end_folder', 'CreatedBy': 'created_by', 'if_list': 'if_list', 'event_list': 'event_list', 'resource_list': 'resource_list', 'wait_for_events': 'wait_for_events', 'events_to_add': 'events_to_add', 'events_to_delete': 'events_to_delete', 'notify_list': 'notify_list', 'job_tag_list': 'job_tag_list', 'action_capture_output_list': 'action_capture_output_list', 'wait_for_events_list': 'wait_for_events_list', 'add_events_list': 'add_events_list', 'delete_events_list': 'delete_events_list', 'condition_list': 'condition_list', 'Type': '_type', 'object_name': 'object_name', 'ConnectionProfile': 'connection_profile', 'Action': 'action', 'Workspace Name': 'workspace_name', 'Run Name': 'run_name', 'Parameters': 'parameters', 'Workspace Params': 'workspace_params', 'Variable': 'variable', 'Status Polling Frequency': 'status_polling_frequency', 'Failure Tolerance': 'failure_tolerance'}
# [DEBUG] Key 'PathElement' not in input data. Skipping.
# [DEBUG] Key 'FileName' not in input data. Skipping.
# [DEBUG] Key 'FilePath' not in input data. Skipping.
# [DEBUG] Key 'Host' not in input data. Skipping.
# [DEBUG] Key 'Application' not in input data. Skipping.
# [DEBUG] Key 'Priority' not in input data. Skipping.
# [DEBUG] Key 'Critical' not in input data. Skipping.
# [DEBUG] Key 'Confirm' not in input data. Skipping.
# [DEBUG] Key 'DaysKeepActive' not in input data. Skipping.
# [DEBUG] Key 'Description' not in input data. Skipping.
# [DEBUG] Key 'DocumentationFile' not in input data. Skipping.
# [DEBUG] Key 'DocumentationUrl' not in input data. Skipping.
# [DEBUG] Key 'RerunLimit' not in input data. Skipping.
# [DEBUG] Key 'Rerun' not in input data. Skipping.
# [DEBUG] Key 'RerunIntervals' not in input data. Skipping.
# [DEBUG] Key 'RerunSpecificTimes' not in input data. Skipping.
# [DEBUG] Key 'PostCommand' not in input data. Skipping.
# [DEBUG] Key 'PreCommand' not in input data. Skipping.
# [DEBUG] Processing field 'run_as' (from key 'RunAs'), type=<class 'str'>, value=workbench
# [DEBUG] Key 'SubApplication' not in input data. Skipping.
# [DEBUG] Key 'TimeZone' not in input data. Skipping.
# [DEBUG] Processing field 'variables' (from key 'Variables'), type=typing.List[typing.Dict[str, str]], value=[{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}]
# [DEBUG] Structuring list field 'variables' with item type 'typing.Dict[str, str]'
# [DEBUG] Key 'When' not in input data. Skipping.
# [DEBUG] Key 'RunOnAllAgentsInGroup' not in input data. Skipping.
# [DEBUG] Key 'Output' not in input data. Skipping.
# [DEBUG] Processing field 'run_as_dummy' (from key 'RunAsDummy'), type=<class 'bool'>, value=True
# [DEBUG] Key 'RetroactiveOrder' not in input data. Skipping.
# [DEBUG] Key 'EndFolder' not in input data. Skipping.
# [DEBUG] Key 'CreatedBy' not in input data. Skipping.
# [DEBUG] Key 'if_list' not in input data. Skipping.
# [DEBUG] Key 'event_list' not in input data. Skipping.
# [DEBUG] Key 'resource_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events' not in input data. Skipping.
# [DEBUG] Key 'events_to_add' not in input data. Skipping.
# [DEBUG] Key 'events_to_delete' not in input data. Skipping.
# [DEBUG] Key 'notify_list' not in input data. Skipping.
# [DEBUG] Key 'job_tag_list' not in input data. Skipping.
# [DEBUG] Key 'action_capture_output_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events_list' not in input data. Skipping.
# [DEBUG] Key 'add_events_list' not in input data. Skipping.
# [DEBUG] Key 'delete_events_list' not in input data. Skipping.
# [DEBUG] Key 'condition_list' not in input data. Skipping.
# [DEBUG] Field '_type' not in init fields. Skipping.
# [DEBUG] Processing field 'object_name' (from key 'object_name'), type=<class 'str'>, value=Jobs2
# [DEBUG] Processing field 'connection_profile' (from key 'ConnectionProfile'), type=<class 'str'>, value=TERRAFORM
# [DEBUG] Processing field 'action' (from key 'Action'), type=<class 'str'>, value=Run Workspace
# [DEBUG] Processing field 'workspace_name' (from key 'Workspace Name'), type=<class 'str'>, value=dealership-demo
# [DEBUG] Processing field 'run_name' (from key 'Run Name'), type=<class 'str'>, value=demorun%%ORDERID
# [DEBUG] Key 'Parameters' not in input data. Skipping.
# [DEBUG] Key 'Workspace Params' not in input data. Skipping.
# [DEBUG] Key 'Variable' not in input data. Skipping.
# [DEBUG] Key 'Status Polling Frequency' not in input data. Skipping.
# [DEBUG] Key 'Failure Tolerance' not in input data. Skipping.
# [DEBUG] Final kwargs for JobTerraform: {'run_as': 'workbench', 'variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'run_as_dummy': True, 'object_name': 'Jobs2', 'connection_profile': 'TERRAFORM', 'action': 'Run Workspace', 'workspace_name': 'dealership-demo', 'run_name': 'demorun%%ORDERID'}
# [DEBUG] extracted Type hint: Job:Databricks
# [DEBUG] resolved Type 'Job:Databricks' to class JobDatabricks
#
# [DEBUG] Deserializing class: JobDatabricks
# [DEBUG] Raw data: {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '658383437534753', 'Parameters': '"params":{}', 'Idempotency Token': 'token_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs3', 'object_name': 'Jobs3'}
# [DEBUG] Field map: {'PathElement': 'path_element', 'FileName': 'file_name', 'FilePath': 'file_path', 'Host': 'host', 'Application': 'application', 'Priority': 'priority', 'Critical': 'critical', 'Confirm': 'confirm', 'DaysKeepActive': 'days_keep_active', 'Description': 'description', 'DocumentationFile': 'documentation_file', 'DocumentationUrl': 'documentation_url', 'RerunLimit': 'rerun_limit', 'Rerun': 'rerun', 'RerunIntervals': 'rerun_intervals', 'RerunSpecificTimes': 'rerun_specific_times', 'PostCommand': 'post_command', 'PreCommand': 'pre_command', 'RunAs': 'run_as', 'SubApplication': 'sub_application', 'TimeZone': 'time_zone', 'Variables': 'variables', 'When': 'when', 'RunOnAllAgentsInGroup': 'run_on_all_agents_in_group', 'Output': 'output', 'RunAsDummy': 'run_as_dummy', 'RetroactiveOrder': 'retroactive_order', 'EndFolder': 'end_folder', 'CreatedBy': 'created_by', 'if_list': 'if_list', 'event_list': 'event_list', 'resource_list': 'resource_list', 'wait_for_events': 'wait_for_events', 'events_to_add': 'events_to_add', 'events_to_delete': 'events_to_delete', 'notify_list': 'notify_list', 'job_tag_list': 'job_tag_list', 'action_capture_output_list': 'action_capture_output_list', 'wait_for_events_list': 'wait_for_events_list', 'add_events_list': 'add_events_list', 'delete_events_list': 'delete_events_list', 'condition_list': 'condition_list', 'Type': '_type', 'object_name': 'object_name', 'ConnectionProfile': 'connection_profile', 'Databricks Job ID': 'databricks_job_id', 'Parameters': 'parameters', 'Idempotency Token': 'idempotency_token', 'Status Polling Frequency': 'status_polling_frequency', 'Failure Tolerance': 'failure_tolerance'}
# [DEBUG] Key 'PathElement' not in input data. Skipping.
# [DEBUG] Key 'FileName' not in input data. Skipping.
# [DEBUG] Key 'FilePath' not in input data. Skipping.
# [DEBUG] Key 'Host' not in input data. Skipping.
# [DEBUG] Key 'Application' not in input data. Skipping.
# [DEBUG] Key 'Priority' not in input data. Skipping.
# [DEBUG] Key 'Critical' not in input data. Skipping.
# [DEBUG] Key 'Confirm' not in input data. Skipping.
# [DEBUG] Key 'DaysKeepActive' not in input data. Skipping.
# [DEBUG] Key 'Description' not in input data. Skipping.
# [DEBUG] Key 'DocumentationFile' not in input data. Skipping.
# [DEBUG] Key 'DocumentationUrl' not in input data. Skipping.
# [DEBUG] Key 'RerunLimit' not in input data. Skipping.
# [DEBUG] Key 'Rerun' not in input data. Skipping.
# [DEBUG] Key 'RerunIntervals' not in input data. Skipping.
# [DEBUG] Key 'RerunSpecificTimes' not in input data. Skipping.
# [DEBUG] Key 'PostCommand' not in input data. Skipping.
# [DEBUG] Key 'PreCommand' not in input data. Skipping.
# [DEBUG] Processing field 'run_as' (from key 'RunAs'), type=<class 'str'>, value=workbench
# [DEBUG] Key 'SubApplication' not in input data. Skipping.
# [DEBUG] Key 'TimeZone' not in input data. Skipping.
# [DEBUG] Key 'Variables' not in input data. Skipping.
# [DEBUG] Key 'When' not in input data. Skipping.
# [DEBUG] Key 'RunOnAllAgentsInGroup' not in input data. Skipping.
# [DEBUG] Key 'Output' not in input data. Skipping.
# [DEBUG] Processing field 'run_as_dummy' (from key 'RunAsDummy'), type=<class 'bool'>, value=True
# [DEBUG] Key 'RetroactiveOrder' not in input data. Skipping.
# [DEBUG] Key 'EndFolder' not in input data. Skipping.
# [DEBUG] Key 'CreatedBy' not in input data. Skipping.
# [DEBUG] Key 'if_list' not in input data. Skipping.
# [DEBUG] Key 'event_list' not in input data. Skipping.
# [DEBUG] Key 'resource_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events' not in input data. Skipping.
# [DEBUG] Key 'events_to_add' not in input data. Skipping.
# [DEBUG] Key 'events_to_delete' not in input data. Skipping.
# [DEBUG] Key 'notify_list' not in input data. Skipping.
# [DEBUG] Key 'job_tag_list' not in input data. Skipping.
# [DEBUG] Key 'action_capture_output_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events_list' not in input data. Skipping.
# [DEBUG] Key 'add_events_list' not in input data. Skipping.
# [DEBUG] Key 'delete_events_list' not in input data. Skipping.
# [DEBUG] Key 'condition_list' not in input data. Skipping.
# [DEBUG] Field '_type' not in init fields. Skipping.
# [DEBUG] Processing field 'object_name' (from key 'object_name'), type=<class 'str'>, value=Jobs3
# [DEBUG] Processing field 'connection_profile' (from key 'ConnectionProfile'), type=<class 'str'>, value=DATABRICKS
# [DEBUG] Processing field 'databricks_job_id' (from key 'Databricks Job ID'), type=<class 'str'>, value=658383437534753
# [DEBUG] Processing field 'parameters' (from key 'Parameters'), type=<class 'str'>, value="params":{}
# [DEBUG] Processing field 'idempotency_token' (from key 'Idempotency Token'), type=<class 'str'>, value=token_%%ORDERID
# [DEBUG] Key 'Status Polling Frequency' not in input data. Skipping.
# [DEBUG] Key 'Failure Tolerance' not in input data. Skipping.
# [DEBUG] Final kwargs for JobDatabricks: {'run_as': 'workbench', 'run_as_dummy': True, 'object_name': 'Jobs3', 'connection_profile': 'DATABRICKS', 'databricks_job_id': '658383437534753', 'parameters': '"params":{}', 'idempotency_token': 'token_%%ORDERID'}
# [DEBUG] extracted Type hint: Job:Databricks
# [DEBUG] resolved Type 'Job:Databricks' to class JobDatabricks
#
# [DEBUG] Deserializing class: JobDatabricks
# [DEBUG] Raw data: {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs4', 'object_name': 'Jobs4'}
# [DEBUG] Field map: {'PathElement': 'path_element', 'FileName': 'file_name', 'FilePath': 'file_path', 'Host': 'host', 'Application': 'application', 'Priority': 'priority', 'Critical': 'critical', 'Confirm': 'confirm', 'DaysKeepActive': 'days_keep_active', 'Description': 'description', 'DocumentationFile': 'documentation_file', 'DocumentationUrl': 'documentation_url', 'RerunLimit': 'rerun_limit', 'Rerun': 'rerun', 'RerunIntervals': 'rerun_intervals', 'RerunSpecificTimes': 'rerun_specific_times', 'PostCommand': 'post_command', 'PreCommand': 'pre_command', 'RunAs': 'run_as', 'SubApplication': 'sub_application', 'TimeZone': 'time_zone', 'Variables': 'variables', 'When': 'when', 'RunOnAllAgentsInGroup': 'run_on_all_agents_in_group', 'Output': 'output', 'RunAsDummy': 'run_as_dummy', 'RetroactiveOrder': 'retroactive_order', 'EndFolder': 'end_folder', 'CreatedBy': 'created_by', 'if_list': 'if_list', 'event_list': 'event_list', 'resource_list': 'resource_list', 'wait_for_events': 'wait_for_events', 'events_to_add': 'events_to_add', 'events_to_delete': 'events_to_delete', 'notify_list': 'notify_list', 'job_tag_list': 'job_tag_list', 'action_capture_output_list': 'action_capture_output_list', 'wait_for_events_list': 'wait_for_events_list', 'add_events_list': 'add_events_list', 'delete_events_list': 'delete_events_list', 'condition_list': 'condition_list', 'Type': '_type', 'object_name': 'object_name', 'ConnectionProfile': 'connection_profile', 'Databricks Job ID': 'databricks_job_id', 'Parameters': 'parameters', 'Idempotency Token': 'idempotency_token', 'Status Polling Frequency': 'status_polling_frequency', 'Failure Tolerance': 'failure_tolerance'}
# [DEBUG] Key 'PathElement' not in input data. Skipping.
# [DEBUG] Key 'FileName' not in input data. Skipping.
# [DEBUG] Key 'FilePath' not in input data. Skipping.
# [DEBUG] Key 'Host' not in input data. Skipping.
# [DEBUG] Key 'Application' not in input data. Skipping.
# [DEBUG] Key 'Priority' not in input data. Skipping.
# [DEBUG] Key 'Critical' not in input data. Skipping.
# [DEBUG] Key 'Confirm' not in input data. Skipping.
# [DEBUG] Key 'DaysKeepActive' not in input data. Skipping.
# [DEBUG] Key 'Description' not in input data. Skipping.
# [DEBUG] Key 'DocumentationFile' not in input data. Skipping.
# [DEBUG] Key 'DocumentationUrl' not in input data. Skipping.
# [DEBUG] Key 'RerunLimit' not in input data. Skipping.
# [DEBUG] Key 'Rerun' not in input data. Skipping.
# [DEBUG] Key 'RerunIntervals' not in input data. Skipping.
# [DEBUG] Key 'RerunSpecificTimes' not in input data. Skipping.
# [DEBUG] Key 'PostCommand' not in input data. Skipping.
# [DEBUG] Key 'PreCommand' not in input data. Skipping.
# [DEBUG] Processing field 'run_as' (from key 'RunAs'), type=<class 'str'>, value=workbench
# [DEBUG] Key 'SubApplication' not in input data. Skipping.
# [DEBUG] Key 'TimeZone' not in input data. Skipping.
# [DEBUG] Key 'Variables' not in input data. Skipping.
# [DEBUG] Key 'When' not in input data. Skipping.
# [DEBUG] Key 'RunOnAllAgentsInGroup' not in input data. Skipping.
# [DEBUG] Key 'Output' not in input data. Skipping.
# [DEBUG] Processing field 'run_as_dummy' (from key 'RunAsDummy'), type=<class 'bool'>, value=True
# [DEBUG] Key 'RetroactiveOrder' not in input data. Skipping.
# [DEBUG] Key 'EndFolder' not in input data. Skipping.
# [DEBUG] Key 'CreatedBy' not in input data. Skipping.
# [DEBUG] Key 'if_list' not in input data. Skipping.
# [DEBUG] Key 'event_list' not in input data. Skipping.
# [DEBUG] Key 'resource_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events' not in input data. Skipping.
# [DEBUG] Key 'events_to_add' not in input data. Skipping.
# [DEBUG] Key 'events_to_delete' not in input data. Skipping.
# [DEBUG] Key 'notify_list' not in input data. Skipping.
# [DEBUG] Key 'job_tag_list' not in input data. Skipping.
# [DEBUG] Key 'action_capture_output_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events_list' not in input data. Skipping.
# [DEBUG] Key 'add_events_list' not in input data. Skipping.
# [DEBUG] Key 'delete_events_list' not in input data. Skipping.
# [DEBUG] Key 'condition_list' not in input data. Skipping.
# [DEBUG] Field '_type' not in init fields. Skipping.
# [DEBUG] Processing field 'object_name' (from key 'object_name'), type=<class 'str'>, value=Jobs4
# [DEBUG] Processing field 'connection_profile' (from key 'ConnectionProfile'), type=<class 'str'>, value=DATABRICKS
# [DEBUG] Processing field 'databricks_job_id' (from key 'Databricks Job ID'), type=<class 'str'>, value=991955986358417
# [DEBUG] Processing field 'parameters' (from key 'Parameters'), type=<class 'str'>, value="params":{}
# [DEBUG] Processing field 'idempotency_token' (from key 'Idempotency Token'), type=<class 'str'>, value=tokeni_%%ORDERID
# [DEBUG] Key 'Status Polling Frequency' not in input data. Skipping.
# [DEBUG] Key 'Failure Tolerance' not in input data. Skipping.
# [DEBUG] Final kwargs for JobDatabricks: {'run_as': 'workbench', 'run_as_dummy': True, 'object_name': 'Jobs4', 'connection_profile': 'DATABRICKS', 'databricks_job_id': '991955986358417', 'parameters': '"params":{}', 'idempotency_token': 'tokeni_%%ORDERID'}
# [DEBUG] extracted Type hint: Job:WebServices
# [DEBUG] resolved Type 'Job:WebServices' to class JobWebServices
#
# [DEBUG] Deserializing class: JobWebServices
# [DEBUG] Raw data: {'Type': 'Job:WebServices', 'ConnectionProfile': 'WeatherAPI', 'Service': 'ForecastService', 'Operation': 'GetWeather', 'RequestType': 'FreeText', 'RunAsDummy': True, 'RunAs': 'WeatherAPI', 'SoapRequest': ['<SOAP-ENV>Request</SOAP-ENV>'], 'Name': 'Jobs5', 'object_name': 'Jobs5'}
# ...
# [DEBUG] Final kwargs for JobAwsSageMaker: {'rerun_limit': AAPIObject(), 'run_as': 'workbench', 'run_as_dummy': True, 'object_name': 'Jobs7', 'connection_profile': 'SAGEMAKER', 'pipeline_name': 'InferencePipeline', 'idempotency_token': 'Token_ControlM_for_SageMaker%%ORDERID', 'add_parameters': 'checked', 'parameters': '{"Name":"input_file", "Value": "file"}', 'retry_pipeline_execution': 'unchecked'}
# [DEBUG] extracted Type hint: Job:Tableau
# [DEBUG] resolved Type 'Job:Tableau' to class JobTableau
#
# [DEBUG] Deserializing class: JobTableau
# [DEBUG] Raw data: {'Type': 'Job:Tableau', 'ConnectionProfile': 'TABLEAU', 'Action': 'Refresh Datasource', 'Datasource Name': 'inventory_forecast', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs8', 'object_name': 'Jobs8'}
# [DEBUG] Field map: {'PathElement': 'path_element', 'FileName': 'file_name', 'FilePath': 'file_path', 'Host': 'host', 'Application': 'application', 'Priority': 'priority', 'Critical': 'critical', 'Confirm': 'confirm', 'DaysKeepActive': 'days_keep_active', 'Description': 'description', 'DocumentationFile': 'documentation_file', 'DocumentationUrl': 'documentation_url', 'RerunLimit': 'rerun_limit', 'Rerun': 'rerun', 'RerunIntervals': 'rerun_intervals', 'RerunSpecificTimes': 'rerun_specific_times', 'PostCommand': 'post_command', 'PreCommand': 'pre_command', 'RunAs': 'run_as', 'SubApplication': 'sub_application', 'TimeZone': 'time_zone', 'Variables': 'variables', 'When': 'when', 'RunOnAllAgentsInGroup': 'run_on_all_agents_in_group', 'Output': 'output', 'RunAsDummy': 'run_as_dummy', 'RetroactiveOrder': 'retroactive_order', 'EndFolder': 'end_folder', 'CreatedBy': 'created_by', 'if_list': 'if_list', 'event_list': 'event_list', 'resource_list': 'resource_list', 'wait_for_events': 'wait_for_events', 'events_to_add': 'events_to_add', 'events_to_delete': 'events_to_delete', 'notify_list': 'notify_list', 'job_tag_list': 'job_tag_list', 'action_capture_output_list': 'action_capture_output_list', 'wait_for_events_list': 'wait_for_events_list', 'add_events_list': 'add_events_list', 'delete_events_list': 'delete_events_list', 'condition_list': 'condition_list', 'Type': '_type', 'object_name': 'object_name', 'ConnectionProfile': 'connection_profile', 'Action': 'action', 'Datasource Name': 'datasource_name', 'Flow Name': 'flow_name', 'Status Polling Frequency': 'status_polling_frequency', 'Failure Tolerance': 'failure_tolerance'}
# [DEBUG] Key 'PathElement' not in input data. Skipping.
# [DEBUG] Key 'FileName' not in input data. Skipping.
# [DEBUG] Key 'FilePath' not in input data. Skipping.
# [DEBUG] Key 'Host' not in input data. Skipping.
# [DEBUG] Key 'Application' not in input data. Skipping.
# [DEBUG] Key 'Priority' not in input data. Skipping.
# [DEBUG] Key 'Critical' not in input data. Skipping.
# [DEBUG] Key 'Confirm' not in input data. Skipping.
# [DEBUG] Key 'DaysKeepActive' not in input data. Skipping.
# [DEBUG] Key 'Description' not in input data. Skipping.
# [DEBUG] Key 'DocumentationFile' not in input data. Skipping.
# [DEBUG] Key 'DocumentationUrl' not in input data. Skipping.
# [DEBUG] Key 'RerunLimit' not in input data. Skipping.
# [DEBUG] Key 'Rerun' not in input data. Skipping.
# [DEBUG] Key 'RerunIntervals' not in input data. Skipping.
# [DEBUG] Key 'RerunSpecificTimes' not in input data. Skipping.
# [DEBUG] Key 'PostCommand' not in input data. Skipping.
# [DEBUG] Key 'PreCommand' not in input data. Skipping.
# [DEBUG] Processing field 'run_as' (from key 'RunAs'), type=<class 'str'>, value=workbench
# [DEBUG] Key 'SubApplication' not in input data. Skipping.
# [DEBUG] Key 'TimeZone' not in input data. Skipping.
# [DEBUG] Key 'Variables' not in input data. Skipping.
# [DEBUG] Key 'When' not in input data. Skipping.
# [DEBUG] Key 'RunOnAllAgentsInGroup' not in input data. Skipping.
# [DEBUG] Key 'Output' not in input data. Skipping.
# [DEBUG] Processing field 'run_as_dummy' (from key 'RunAsDummy'), type=<class 'bool'>, value=True
# [DEBUG] Key 'RetroactiveOrder' not in input data. Skipping.
# [DEBUG] Key 'EndFolder' not in input data. Skipping.
# [DEBUG] Key 'CreatedBy' not in input data. Skipping.
# [DEBUG] Key 'if_list' not in input data. Skipping.
# [DEBUG] Key 'event_list' not in input data. Skipping.
# [DEBUG] Key 'resource_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events' not in input data. Skipping.
# [DEBUG] Key 'events_to_add' not in input data. Skipping.
# [DEBUG] Key 'events_to_delete' not in input data. Skipping.
# [DEBUG] Key 'notify_list' not in input data. Skipping.
# [DEBUG] Key 'job_tag_list' not in input data. Skipping.
# [DEBUG] Key 'action_capture_output_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events_list' not in input data. Skipping.
# [DEBUG] Key 'add_events_list' not in input data. Skipping.
# [DEBUG] Key 'delete_events_list' not in input data. Skipping.
# [DEBUG] Key 'condition_list' not in input data. Skipping.
# [DEBUG] Field '_type' not in init fields. Skipping.
# [DEBUG] Processing field 'object_name' (from key 'object_name'), type=<class 'str'>, value=Jobs8
# [DEBUG] Processing field 'connection_profile' (from key 'ConnectionProfile'), type=<class 'str'>, value=TABLEAU
# [DEBUG] Processing field 'action' (from key 'Action'), type=<class 'str'>, value=Refresh Datasource
# [DEBUG] Processing field 'datasource_name' (from key 'Datasource Name'), type=<class 'str'>, value=inventory_forecast
# [DEBUG] Key 'Flow Name' not in input data. Skipping.
# [DEBUG] Key 'Status Polling Frequency' not in input data. Skipping.
# [DEBUG] Key 'Failure Tolerance' not in input data. Skipping.
# [DEBUG] Final kwargs for JobTableau: {'run_as': 'workbench', 'run_as_dummy': True, 'object_name': 'Jobs8', 'connection_profile': 'TABLEAU', 'action': 'Refresh Datasource', 'datasource_name': 'inventory_forecast'}
# [DEBUG] Key 'folder_client_data_list' not in input data. Skipping.
# [DEBUG] Field '_type' not in init fields. Skipping.
# [DEBUG] Processing field 'object_name' (from key 'object_name'), type=<class 'str'>, value=Folder_Sanity_Integration_Factory
# [DEBUG] Key 'Priority' not in input data. Skipping.
# [DEBUG] Key 'Application' not in input data. Skipping.
# [DEBUG] Key 'CreatedBy' not in input data. Skipping.
# [DEBUG] Key 'Confirm' not in input data. Skipping.
# [DEBUG] Key 'DaysKeepActive' not in input data. Skipping.
# [DEBUG] Key 'Description' not in input data. Skipping.
# [DEBUG] Key 'DaysKeepActiveIfNotOk' not in input data. Skipping.
# [DEBUG] Key 'ActiveRetentionPolicy' not in input data. Skipping.
# [DEBUG] Processing field 'run_as' (from key 'RunAs'), type=<class 'str'>, value=workbench
# [DEBUG] Key 'DocumentationFile' not in input data. Skipping.
# [DEBUG] Key 'DocumentationUrl' not in input data. Skipping.
# [DEBUG] Key 'MemberLibrary' not in input data. Skipping.
# [DEBUG] Key 'StatisticsCalendar' not in input data. Skipping.
# [DEBUG] Key 'SAC' not in input data. Skipping.
# [DEBUG] Key 'MustEnd' not in input data. Skipping.
# [DEBUG] Key 'RerunLimit' not in input data. Skipping.
# [DEBUG] Key 'Rerun' not in input data. Skipping.
# [DEBUG] Key 'RerunIntervals' not in input data. Skipping.
# [DEBUG] Key 'RerunSpecificTimes' not in input data. Skipping.
# [DEBUG] Key 'SubApplication' not in input data. Skipping.
# [DEBUG] Key 'TimeZone' not in input data. Skipping.
# [DEBUG] Key 'Variables' not in input data. Skipping.
# [DEBUG] Key 'AdjustEvents' not in input data. Skipping.
# [DEBUG] Key 'When' not in input data. Skipping.
# [DEBUG] Key 'if_list' not in input data. Skipping.
# [DEBUG] Key 'event_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events' not in input data. Skipping.
# [DEBUG] Key 'events_to_add' not in input data. Skipping.
# [DEBUG] Key 'events_to_delete' not in input data. Skipping.
# [DEBUG] Key 'notify_list' not in input data. Skipping.
# [DEBUG] Key 'resource_lock_list' not in input data. Skipping.
# [DEBUG] Key 'sub_folder_list' not in input data. Skipping.
# [DEBUG] Key 'wait_for_events_list' not in input data. Skipping.
# [DEBUG] Key 'add_events_list' not in input data. Skipping.
# [DEBUG] Key 'delete_events_list' not in input data. Skipping.
# [DEBUG] Final kwargs for Folder: {'controlm_server': 'workbench', 'job_list': [JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Databricks', object_name='Jobs1', connection_profile='DATABRICKS', databricks_job_id='991955986358417', parameters='"params":{}', idempotency_token='tokeni_%%ORDERID', status_polling_frequency=None, failure_tolerance=None), JobTerraform(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Terraform', object_name='Jobs2', connection_profile='TERRAFORM', action='Run Workspace', workspace_name='dealership-demo', run_name='demorun%%ORDERID', parameters=None, workspace_params=None, variable=None, status_polling_frequency=None, failure_tolerance=None), JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Databricks', object_name='Jobs3', connection_profile='DATABRICKS', databricks_job_id='658383437534753', parameters='"params":{}', idempotency_token='token_%%ORDERID', status_polling_frequency=None, failure_tolerance=None), JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list ...
# [Folder(controlm_server='workbench', order_method=None, folder_library=None, site_standard=None, business_fields=[], job_list=[JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Databricks', object_name='Jobs1', connection_profile='DATABRICKS', databricks_job_id='991955986358417', parameters='"params":{}', idempotency_token='tokeni_%%ORDERID', status_polling_frequency=None, failure_tolerance=None), JobTerraform(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Terraform', object_name='Jobs2', connection_profile='TERRAFORM', action='Run Workspace', workspace_name='dealership-demo', run_name='demorun%%ORDERID', parameters=None, workspace_params=None, variable=None, status_polling_frequency=None, failure_tolerance=None), JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Databricks', object_name='Jobs3', connection_profile='DATABRICKS', databricks_job_id='658383437534753', parameters='"params":{}', idempotency_token='token_%%ORDERID', status_polling_frequency=None, failure_tolerance=None), JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], ev ...

# %%
import time as t
from ctm_python_client.core.workflow import Workflow, WorkflowDefaults
from ctm_python_client.core.comm import Environment, EnvironmentMode
from aapi import *

workflow1 = Workflow(Environment.create_workbench('workbench'), WorkflowDefaults(run_as='workbench'))

workflow1.clear_all()
run_as_dummy = True

databricksLoad = JobDatabricks(
    'LoadForecasts',
    connection_profile='DATABRICKS',
    databricks_job_id='991955986358417',
    parameters='"params":{}',
    idempotency_token = 'tokeni_%%ORDERID',
    run_as_dummy= run_as_dummy
)

terraform_scale_databricks = JobTerraform(
    'TerraformScale',
    connection_profile='TERRAFORM',
    action='Run Workspace',
    workspace_name='dealership-demo',
    run_name= "demorun%%ORDERID",
    variables = [{"min_workers":"4"},{"max_workers":"10"}],
    run_as_dummy= run_as_dummy
)

ExtractInventoryHistory = JobDatabricks(
    'ExtractInventoryHistory',
    connection_profile='DATABRICKS',
    databricks_job_id='658383437534753',
    parameters='"params":{}',
    idempotency_token = 'token_%%ORDERID',
    run_as_dummy= run_as_dummy
)

web_service_job = JobWebServices(
    object_name='WeatherService',
    run_as_dummy=run_as_dummy,
    connection_profile='WeatherAPI',
    service='ForecastService',
    operation='GetWeather',
    request_type=JobWebServices.RequestType.FreeText,
    soap_request=['<SOAP-ENV>Request</SOAP-ENV>']
)


folder1 = Folder('Folder_Sanity_1',
                controlm_server='workbench',
                job_list=[databricksLoad, terraform_scale_databricks])
folder2 = Folder('Folder_Sanity_2',
                controlm_server='workbench',
                job_list=[ExtractInventoryHistory, web_service_job])

workflow1.add(folder1)
workflow1.add(folder2)

workflow1.build()
workflow1.deploy()
run = workflow1.run()
jobs = Workflow.get_jobs_list_of_folders(Environment.create_workbench('workbench'),server="workbench", folder="Folder_Sanity_*")

jobs1 = workflow1.get_jobs_draft_with_workflow_instance(server="workbench", folder="Folder_Sanity_*")
print(jobs)
# Out:
# [DEBUG] Deserializing class: Folder
# [DEBUG] Raw data: {'Type': 'Folder', 'ControlmServer': 'workbench', 'RunAs': 'workbench', 'Jobs': [{'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}, {'Type': 'Job:Terraform', 'ConnectionProfile': 'TERRAFORM', 'Action': 'Run Workspace', 'Workspace Name': 'dealership-demo', 'Run Name': 'demorun%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'Name': 'Jobs2', 'object_name': 'Jobs2'}], 'object_name': 'Folder_Sanity_1'}
# [DEBUG] Extracted Type hint: Job:Databricks
# [DEBUG] Resolved Type 'Job:Databricks' to class JobDatabricks
#
# [DEBUG] Deserializing class: JobDatabricks
# [DEBUG] Raw data: {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}
# [DEBUG] Extracted Type hint: Job:Terraform
# [DEBUG] Resolved Type 'Job:Terraform' to class JobTerraform
#
# [DEBUG] Deserializing class: JobTerraform
# [DEBUG] Raw data: {'Type': 'Job:Terraform', 'ConnectionProfile': 'TERRAFORM', 'Action': 'Run Workspace', 'Workspace Name': 'dealership-demo', 'Run Name': 'demorun%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'Name': 'Jobs2', 'object_name': 'Jobs2'}
#
# [DEBUG] Deserializing class: Folder
# [DEBUG] Raw data: {'Type': 'Folder', 'ControlmServer': 'workbench', 'RunAs': 'workbench', 'Jobs': [{'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '658383437534753', 'Parameters': '"params":{}', 'Idempotency Token': 'token_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}, {'Type': 'Job:WebServices', 'ConnectionProfile': 'WeatherAPI', 'Service': 'ForecastService', 'Operation': 'GetWeather', 'RequestType': 'FreeText', 'RunAsDummy': True, 'RunAs': 'WeatherAPI', 'SoapRequest': ['<SOAP-ENV>Request</SOAP-ENV>'], 'Name': 'Jobs2', 'object_name': 'Jobs2'}], 'object_name': 'Folder_Sanity_2'}
# [DEBUG] Extracted Type hint: Job:Databricks
# [DEBUG] Resolved Type 'Job:Databricks' to class JobDatabricks
#
# [DEBUG] Deserializing class: JobDatabricks
# [DEBUG] Raw data: {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '658383437534753', 'Parameters': '"params":{}', 'Idempotency Token': 'token_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}
# [DEBUG] Extracted Type hint: Job:WebServices
# [DEBUG] Resolved Type 'Job:WebServices' to class JobWebServices
#
# [DEBUG] Deserializing class: JobWebServices
# [DEBUG] Raw data: {'Type': 'Job:WebServices', 'ConnectionProfile': 'WeatherAPI', 'Service': 'ForecastService', 'Operation': 'GetWeather', 'RequestType': 'FreeText', 'RunAsDummy': True, 'RunAs': 'WeatherAPI', 'SoapRequest': ['<SOAP-ENV>Request</SOAP-ENV>'], 'Name': 'Jobs2', 'object_name': 'Jobs2'}
#
# [DEBUG] Deserializing class: Folder
# [DEBUG] Raw data: {'Type': 'Folder', 'ControlmServer': 'workbench', 'RunAs': 'workbench', 'Jobs': [{'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}, {'Type': 'Job:Terraform', 'ConnectionProfile': 'TERRAFORM', 'Action': 'Run Workspace', 'Workspace Name': 'dealership-demo', 'Run Name': 'demorun%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'Name': 'Jobs2', 'object_name': 'Jobs2'}], 'object_name': 'Folder_Sanity_1'}
# [DEBUG] Extracted Type hint: Job:Databricks
# [DEBUG] Resolved Type 'Job:Databricks' to class JobDatabricks
#
# [DEBUG] Deserializing class: JobDatabricks
# [DEBUG] Raw data: {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '991955986358417', 'Parameters': '"params":{}', 'Idempotency Token': 'tokeni_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}
# [DEBUG] Extracted Type hint: Job:Terraform
# [DEBUG] Resolved Type 'Job:Terraform' to class JobTerraform
#
# [DEBUG] Deserializing class: JobTerraform
# [DEBUG] Raw data: {'Type': 'Job:Terraform', 'ConnectionProfile': 'TERRAFORM', 'Action': 'Run Workspace', 'Workspace Name': 'dealership-demo', 'Run Name': 'demorun%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Variables': [{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], 'Name': 'Jobs2', 'object_name': 'Jobs2'}
#
# [DEBUG] Deserializing class: Folder
# [DEBUG] Raw data: {'Type': 'Folder', 'ControlmServer': 'workbench', 'RunAs': 'workbench', 'Jobs': [{'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '658383437534753', 'Parameters': '"params":{}', 'Idempotency Token': 'token_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}, {'Type': 'Job:WebServices', 'ConnectionProfile': 'WeatherAPI', 'Service': 'ForecastService', 'Operation': 'GetWeather', 'RequestType': 'FreeText', 'RunAsDummy': True, 'RunAs': 'WeatherAPI', 'SoapRequest': ['<SOAP-ENV>Request</SOAP-ENV>'], 'Name': 'Jobs2', 'object_name': 'Jobs2'}], 'object_name': 'Folder_Sanity_2'}
# [DEBUG] Extracted Type hint: Job:Databricks
# [DEBUG] Resolved Type 'Job:Databricks' to class JobDatabricks
#
# [DEBUG] Deserializing class: JobDatabricks
# [DEBUG] Raw data: {'Type': 'Job:Databricks', 'ConnectionProfile': 'DATABRICKS', 'Databricks Job ID': '658383437534753', 'Parameters': '"params":{}', 'Idempotency Token': 'token_%%ORDERID', 'RunAsDummy': True, 'RunAs': 'workbench', 'Name': 'Jobs1', 'object_name': 'Jobs1'}
# [DEBUG] Extracted Type hint: Job:WebServices
# [DEBUG] Resolved Type 'Job:WebServices' to class JobWebServices
#
# [DEBUG] Deserializing class: JobWebServices
# [DEBUG] Raw data: {'Type': 'Job:WebServices', 'ConnectionProfile': 'WeatherAPI', 'Service': 'ForecastService', 'Operation': 'GetWeather', 'RequestType': 'FreeText', 'RunAsDummy': True, 'RunAs': 'WeatherAPI', 'SoapRequest': ['<SOAP-ENV>Request</SOAP-ENV>'], 'Name': 'Jobs2', 'object_name': 'Jobs2'}
# [Folder(controlm_server='workbench', order_method=None, folder_library=None, site_standard=None, business_fields=[], job_list=[JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Databricks', object_name='Jobs1', connection_profile='DATABRICKS', databricks_job_id='991955986358417', parameters='"params":{}', idempotency_token='tokeni_%%ORDERID', status_polling_frequency=None, failure_tolerance=None), JobTerraform(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[{'min_workers': '4'}, {'max_workers': '10'}, {'UCM-WORKSPACEBODY3': ''}, {'UCM-WORKSPACEBODY1': ''}], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[], condition_list=[], _type='Job:Terraform', object_name='Jobs2', connection_profile='TERRAFORM', action='Run Workspace', workspace_name='dealership-demo', run_name='demorun%%ORDERID', parameters=None, workspace_params=None, variable=None, status_polling_frequency=None, failure_tolerance=None)], folder_client_data_list=[], _type='Folder', object_name='Folder_Sanity_1', priority=None, application=None, created_by=None, confirm=None, days_keep_active=None, description=None, days_keep_active_if_not_ok=None, active_retention_policy=None, run_as='workbench', documentation_file=None, documentation_url=None, member_library=None, statistics_calendar=None, sac=None, must_end=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, sub_application=None, time_zone=None, variables=[], adjust_events=None, when=None, if_list=[], event_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], resource_lock_list=[], sub_folder_list=[], wait_for_events_list=[], add_events_list=[], delete_events_list=[]), Folder(controlm_server='workbench', order_method=None, folder_library=None, site_standard=None, business_fields=[], job_list=[JobDatabricks(path_element=None, file_name=None, file_path=None, host=None, application=None, priority=None, critical=None, confirm=None, days_keep_active=None, description=None, documentation_file=None, documentation_url=None, rerun_limit=None, rerun=None, rerun_intervals=None, rerun_specific_times=None, post_command=None, pre_command=None, run_as='workbench', sub_application=None, time_zone=None, variables=[], when=None, run_on_all_agents_in_group=None, output=None, run_as_dummy=True, retroactive_order=None, end_folder=None, created_by=None, if_list=[], event_list=[], resource_list=[], wait_for_events=[], events_to_add=[], events_to_delete=[], notify_list=[], job_tag_list=[], action_capture_output_list=[], wait_for_events_list=[], add_events_list=[], delete ...

# %%
import time as t
from ctm_python_client.core.workflow import Workflow, WorkflowDefaults
from ctm_python_client.core.comm import Environment, EnvironmentMode
from aapi import *

workflow1 = Workflow(Environment.create_workbench('workbench'), WorkflowDefaults(run_as='workbench'))

workflow1.clear_all()
run_as_dummy = True

databricksLoad = JobDatabricks(
    'LoadForecasts',
    connection_profile='DATABRICKS',
    databricks_job_id='991955986358417',
    parameters='"params":{}',
    idempotency_token = 'tokeni_%%ORDERID',
    run_as_dummy= run_as_dummy
)

terraform_scale_databricks = JobTerraform(
    'TerraformScale',
    connection_profile='TERRAFORM',
    action='Run Workspace',
    workspace_name='dealership-demo',
    run_name= "demorun%%ORDERID",
    variables = [{"min_workers":"4"},{"max_workers":"10"}],
    run_as_dummy= run_as_dummy
)

ExtractInventoryHistory = JobDatabricks(
    'ExtractInventoryHistory',
    connection_profile='DATABRICKS',
    databricks_job_id='658383437534753',
    parameters='"params":{}',
    idempotency_token = 'token_%%ORDERID',
    run_as_dummy= run_as_dummy
)

web_service_job = JobWebServices(
    object_name='WeatherService',
    run_as_dummy=run_as_dummy,
    connection_profile='WeatherAPI',
    service='ForecastService',
    operation='GetWeather',
    request_type=JobWebServices.RequestType.FreeText,
    soap_request=['<SOAP-ENV>Request</SOAP-ENV>']
)


folder1 = Folder('Folder_Sanity_1',
                controlm_server='workbench',
                job_list=[databricksLoad, terraform_scale_databricks])
folder2 = Folder('Folder_Sanity_2',
                controlm_server='workbench',
                job_list=[ExtractInventoryHistory, web_service_job])

workflow1.add(folder1)
workflow1.add(folder2)

workflow1.build()
workflow1.deploy()

workflow2 = Workflow.get_jobs(Environment.create_workbench('workbench'),server="workbench", folder="Folder_Sanity_*")


# print(workflow1._definitions['Folder_Sanity_2'].job_list[1].dumps_aapi(indent=4))
# print(workflow2._definitions['Folder_Sanity_2'].job_list[1].dumps_aapi(indent=4))
print(workflow2)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[2], line 6
#       3 from ctm_python_client.core.comm import Environment, EnvironmentMode
#       4 from aapi import *
# ----> 6 workflow1 = Workflow(Environment.create_workbench('workbench'), WorkflowDefaults(run_as='workbench'))
#       8 workflow1.clear_all()
#       9 run_as_dummy = True
#
# File C:\projects\ctm-python-client\src\ctm_python_client\core\workflow.py:368, in Workflow.__init__(self, environment, defaults, skip_initial_authentication)
#     364     self.aapiclient = OnPremAAPIClient(
#     365         environment.endpoint, environment.credentials)
#     367 if not skip_initial_authentication:
# --> 368     self.authenticate()
#
# File C:\projects\ctm-python-client\src\ctm_python_client\core\workflow.py:371, in Workflow.authenticate(self)
#     370 def authenticate(self):
# --> 371     self.aapiclient.authenticate()
#
# File C:\projects\ctm-python-client\src\ctm_python_client\core\comm.py:80, in OnPremAAPIClient.authenticate(self)
#      77 self.apiclient.configuration.verify_ssl = False
#      78 self.apiclient.configuration.api_key_prefix['Authorization'] = 'Bearer'
# ---> 80 token = self.session_api.do_login(
#      81     {
#      82         'username': self.credentials.get_username(),
#      83         'password': self.credentials.get_password()
#      84     }
#      85 ).token
#      86 self.apiclient.configuration.api_key['Authorization'] = token
#
# File C:\projects\ctm-python-client\src\clients\ctm_api_client\api\session_api.py:55, in SessionApi.do_login(self, credentials, **kwargs)
#      53     return self.do_login_with_http_info(credentials, **kwargs)  # noqa: E501
#      54 else:
# ---> 55     (data) = self.do_login_with_http_info(credentials, **kwargs)  # noqa: E501
#      56     return data
#
# File C:\projects\ctm-python-client\src\clients\ctm_api_client\api\session_api.py:119, in SessionApi.do_login_with_http_info(self, credentials, **kwargs)
#     116 # Authentication setting
#     117 auth_settings = []  # noqa: E501
# --> 119 return self.api_client.call_api(
#     120     "/session/login",
#     121     "POST",
#     122     path_params,
#     123     query_params,
#     124     header_params,
#     125     body=body_params,
#     126     post_params=form_params,
#     127     files=local_var_files,
#     128     response_type="LoginResult",  # noqa: E501
#     129     auth_settings=auth_settings,
#     130     async_req=params.get("async_req"),
#     131     _return_http_data_only=params.get("_return_http_data_only"),
#     132     _preload_content=params.get("_preload_content", True),
#     133     _request_timeout=params.get("_request_timeout"),
#     134     collection_formats=collection_formats,
#     135 )
#
# File C:\projects\ctm-python-client\src\clients\ctm_api_client\api_client.py:353, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     316 """Makes the HTTP request (synchronous) and returns deserialized data.
#     317
#     318 To make an async request, set the async_req parameter.
#    (...)    350     then the method will return the response directly.
#     351 """
#     352 if not async_req:
# --> 353     return self.__call_api(
#     354         resource_path,
#     355         method,
#     356         path_params,
#     357         query_params,
#     358         header_params,
#     359         body,
#     360         post_params,
#     361         files,
#     362         response_type,
#     363         auth_settings,
#     364         _return_http_data_only,
#     365         collection_formats,
#     366         _preload_content,
#     367         _request_timeout,
#     368     )
#     369 else:
#     370     thread = self.pool.apply_async(
#     371         self.__call_api,
#     372         (
#    (...)    387         ),
#     388     )
#
# File C:\projects\ctm-python-client\src\clients\ctm_api_client\api_client.py:167, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     164 url = self.configuration.host + resource_path
#     166 # perform request and return response
# --> 167 response_data = self.request(
#     168     method,
#     169     url,
#     170     query_params=query_params,
#     171     headers=header_params,
#     172     post_params=post_params,
#     173     body=body,
#     174     _preload_content=_preload_content,
#     175     _request_timeout=_request_timeout,
#     176 )
#     178 self.last_response = response_data
#     180 return_data = response_data
#
# File C:\projects\ctm-python-client\src\clients\ctm_api_client\api_client.py:430, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     420     return self.rest_client.OPTIONS(
#     421         url,
#     422         query_params=query_params,
#    (...)    427         body=body,
#     428     )
#     429 elif method == "POST":
# --> 430     return self.rest_client.POST(
#     431         url,
#     432         query_params=query_params,
#     433         headers=headers,
#     434         post_params=post_params,
#     435         _preload_content=_preload_content,
#     436         _request_timeout=_request_timeout,
#     437         body=body,
#     438     )
#     439 elif method == "PUT":
#     440     return self.rest_client.PUT(
#     441         url,
#     442         query_params=query_params,
#    (...)    447         body=body,
#     448     )
#
# File C:\projects\ctm-python-client\src\clients\ctm_api_client\rest.py:339, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     329 def POST(
#     330     self,
#     331     url,
#    (...)    337     _request_timeout=None,
#     338 ):
# --> 339     return self.request(
#     340         "POST",
#     341         url,
#     342         headers=headers,
#     343         query_params=query_params,
#     344         post_params=post_params,
#     345         _preload_content=_preload_content,
#     346         _request_timeout=_request_timeout,
#     347         body=body,
#     348     )
#
# File C:\projects\ctm-python-client\src\clients\ctm_api_client\rest.py:251, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     248     logger.debug("response body: %s", r.data)
#     250 if not 200 <= r.status <= 299:
# --> 251     raise ApiException(http_resp=r)
#     253 return r
#
# ApiException: (500)
# Reason:
# HTTP response headers: HTTPHeaderDict({'X-Content-Type-Options': 'nosniff', 'Pragma': 'no-cache', 'X-Frame-Options': 'SAMEORIGIN', 'Referrer-Policy': 'no-referrer', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Cache-Control': 'no-cache, no-store, private, must-revalidate, max-age=0, no-transform', 'Content-Security-Policy': "object-src 'none'; base-uri 'self'; sandbox allow-scripts allow-popups allow-forms allow-top-navigation allow-presentation allow-same-origin allow-downloads allow-popups-to-escape-sandbox; report-uri /csp-violation-report-endpoint/; form-action 'self'; frame-ancestors 'self';", 'hstsMaxAgeSeconds': '31536000', 'X-XSS-Protection': '1; mode=block', 'Expect-CT': 'max-age=120, enforce', 'vary': 'origin,accept-encoding', 'Set-Cookie': 'JSESSIONID=F941664439616F7D8B1939EA25B5F82A; Path=/automation-api; Secure; HttpOnly', 'Server': 'Web Server', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Date': 'Tue, 13 May 2025 06:47:19 GMT', 'Connection': 'close'})
# HTTP response body: {
#   "errors" : [ {
#     "message" : "Failed to login: Incorrect username or password"
#   } ]
# }

# %%
import time as t
from ctm_python_client.core.workflow import Workflow, WorkflowDefaults
from ctm_python_client.core.comm import Environment
from aapi import *

workflow = Workflow(Environment.create_workbench('workbench'), WorkflowDefaults(run_as='workbench'))

workflow.clear_all()
run_as_dummy = True

databricksLoad = JobDatabricks(
    'LoadForecasts',
    connection_profile='DATABRICKS',
    databricks_job_id='991955986358417',
    parameters='"params":{}',
    idempotency_token='tokeni_%%ORDERID',
    run_as_dummy=run_as_dummy
)

terraform_scale_databricks = JobTerraform(
    'TerraformScale',
    connection_profile='TERRAFORM',
    action='Run Workspace',
    workspace_name='dealership-demo',
    run_name="demorun%%ORDERID",
    variables=[{"min_workers": "4"}, {"max_workers": "10"}],
    run_as_dummy=run_as_dummy
)

ExtractInventoryHistory = JobDatabricks(
    'ExtractInventoryHistory',
    connection_profile='DATABRICKS',
    databricks_job_id='658383437534753',
    parameters='"params":{}',
    idempotency_token='token_%%ORDERID',
    run_as_dummy=run_as_dummy
)

web_service_job = JobWebServices(
    object_name='WeatherService',
    run_as_dummy=run_as_dummy,
    connection_profile='WeatherAPI',
    service='ForecastService',
    operation='GetWeather',
    request_type=JobWebServices.RequestType.FreeText,
    soap_request=['<SOAP-ENV>Request</SOAP-ENV>']
)

query_job = JobDatabaseSQLScript(
    object_name='QueryWeather',
    run_as_dummy=run_as_dummy,
    sql_script='UPDATE weather SET forecast="sunny" WHERE city="Seattle"',
    connection_profile='db_profile'
)

sagemaker_job = JobAwsSageMaker(
    f'InventoryForecastModel',
    connection_profile='SAGEMAKER',
    pipeline_name='InferencePipeline',
    idempotency_token='Token_ControlM_for_SageMaker%%ORDERID',
    add_parameters='checked',
    parameters='{"Name":"input_file", "Value": "file"}',
    run_as_dummy=run_as_dummy,
    retry_pipeline_execution='unchecked',
    rerun_limit=Job.RerunLimit(times='5')
)

tableau_refresh = JobTableau(
    'TableauRefresh',
    connection_profile='TABLEAU',
    action="Refresh Datasource",
    datasource_name="inventory_forecast",
    run_as_dummy=run_as_dummy
)

folder1 = Folder('Folder_Sanity_1',
                 controlm_server='workbench',
                 job_list=[databricksLoad, terraform_scale_databricks, databricksLoad])

folder2 = Folder('Folder_Sanity_2',
                 controlm_server='workbench',
                 job_list=[web_service_job, query_job, sagemaker_job, tableau_refresh])

workflow.add(folder1)
workflow.add(folder2)

workflow.build()
workflow.deploy()

workflow2 = Workflow.get_jobs(Environment.create_workbench('workbench'), server="workbench", folder="Folder_Sanity_*")

print(workflow2)

# Folder_Sanity_1
print("=== Folder_Sanity_1 - Job 0 (databricksLoad) ===")
print(workflow._definitions['Folder_Sanity_1'].job_list[0].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_1'].job_list[0].dumps_aapi(indent=4))

print("=== Folder_Sanity_1 - Job 1 (terraform_scale_databricks) ===")
print(workflow._definitions['Folder_Sanity_1'].job_list[1].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_1'].job_list[1].dumps_aapi(indent=4))

print("=== Folder_Sanity_1 - Job 2 (databricksLoad again) ===")
print(workflow._definitions['Folder_Sanity_1'].job_list[2].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_1'].job_list[2].dumps_aapi(indent=4))

# Folder_Sanity_2
print("=== Folder_Sanity_2 - Job 0 (web_service_job) ===")
print(workflow._definitions['Folder_Sanity_2'].job_list[0].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_2'].job_list[0].dumps_aapi(indent=4))

print("=== Folder_Sanity_2 - Job 1 (query_job) ===")
print(workflow._definitions['Folder_Sanity_2'].job_list[1].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_2'].job_list[1].dumps_aapi(indent=4))

print("=== Folder_Sanity_2 - Job 2 (sagemaker_job) ===")
print(workflow._definitions['Folder_Sanity_2'].job_list[2].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_2'].job_list[2].dumps_aapi(indent=4))

print("=== Folder_Sanity_2 - Job 3 (tableau_refresh) ===")
print(workflow._definitions['Folder_Sanity_2'].job_list[3].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_2'].job_list[3].dumps_aapi(indent=4))
# Out:
# <ctm_python_client.core.workflow.Workflow object at 0x0000028D4E4A3D10>
# === Folder_Sanity_1 - Job 0 (databricksLoad) ===
# {
#     "Type": "Job:Databricks",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "DATABRICKS",
#     "Databricks Job ID": "991955986358417",
#     "Parameters": "\"params\":{}",
#     "Idempotency Token": "tokeni_%%ORDERID"
# }
# {
#     "Type": "Job:Databricks",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "DATABRICKS",
#     "Databricks Job ID": "991955986358417",
#     "Parameters": "\"params\":{}",
#     "Idempotency Token": "tokeni_%%ORDERID"
# }
# === Folder_Sanity_1 - Job 1 (terraform_scale_databricks) ===
# {
#     "Type": "Job:Terraform",
#     "RunAs": "workbench",
#     "Variables": [
#         {
#             "min_workers": "4"
#         },
#         {
#             "max_workers": "10"
#         }
#     ],
#     "RunAsDummy": true,
#     "ConnectionProfile": "TERRAFORM",
#     "Action": "Run Workspace",
#     "Workspace Name": "dealership-demo",
#     "Run Name": "demorun%%ORDERID"
# }
# {
#     "Type": "Job:Terraform",
#     "RunAs": "workbench",
#     "Variables": [
#         {
#             "min_workers": "4"
#         },
#         {
#             "max_workers": "10"
#         },
#         {
#             "UCM-WORKSPACEBODY3": ""
#         },
#         {
#             "UCM-WORKSPACEBODY1": ""
#         }
#     ],
#     "RunAsDummy": true,
#     "ConnectionProfile": "TERRAFORM",
#     "Action": "Run Workspace",
#     "Workspace Name": "dealership-demo",
#     "Run Name": "demorun%%ORDERID"
# }
# === Folder_Sanity_1 - Job 2 (databricksLoad again) ===
# {
#     "Type": "Job:Databricks",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "DATABRICKS",
#     "Databricks Job ID": "991955986358417",
#     "Parameters": "\"params\":{}",
#     "Idempotency Token": "tokeni_%%ORDERID"
# }
# {
#     "Type": "Job:Databricks",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "DATABRICKS",
#     "Databricks Job ID": "991955986358417",
#     "Parameters": "\"params\":{}",
#     "Idempotency Token": "tokeni_%%ORDERID"
# }
# === Folder_Sanity_2 - Job 0 (web_service_job) ===
# {
#     "Type": "Job:WebServices",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "WeatherAPI",
#     "Service": "ForecastService",
#     "Operation": "GetWeather",
#     "RequestType": "FreeText",
#     "SoapRequest": [
#         "<SOAP-ENV>Request</SOAP-ENV>"
#     ]
# }
# {
#     "Type": "Job:WebServices",
#     "RunAs": "WeatherAPI",
#     "RunAsDummy": true,
#     "ConnectionProfile": "WeatherAPI",
#     "Service": "ForecastService",
#     "Operation": "GetWeather",
#     "RequestType": "FreeText",
#     "SoapRequest": [
#         "<SOAP-ENV>Request</SOAP-ENV>"
#     ]
# }
# === Folder_Sanity_2 - Job 1 (query_job) ===
# {
#     "Type": "Job:Database:SQLScript",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "db_profile",
#     "SQLScript": "UPDATE weather SET forecast=\"sunny\" WHERE city=\"Seattle\""
# }
# {
#     "Type": "Job:Database:SQLScript",
#     "RunAs": "db_profile",
#     "RunAsDummy": true,
#     "ConnectionProfile": "db_profile",
#     "SQLScript": "UPDATE weather SET forecast=\"sunny\" WHERE city=\"Seattle\""
# }
# === Folder_Sanity_2 - Job 2 (sagemaker_job) ===
# {
#     "Type": "Job:AWS SageMaker",
#     "RerunLimit": {
#         "Times": "5"
#     },
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "SAGEMAKER",
#     "Pipeline Name": "InferencePipeline",
#     "Idempotency Token": "Token_ControlM_for_SageMaker%%ORDERID",
#     "Add Parameters": "checked",
#     "Parameters": "{\"Name\":\"input_file\", \"Value\": \"file\"}",
#     "Retry Pipeline Execution": "unchecked"
# }
# {
#     "Type": "Job:AWS SageMaker",
#     "RerunLimit": {
#         "Times": "5"
#     },
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "SAGEMAKER",
#     "Pipeline Name": "InferencePipeline",
#     "Idempotency Token": "Token_ControlM_for_SageMaker%%ORDERID",
#     "Add Parameters": "checked",
#     "Parameters": "{\"Name\":\"input_file\", \"Value\": \"file\"}",
#     "Retry Pipeline Execution": "unchecked"
# }
# === Folder_Sanity_2 - Job 3 (tableau_refresh) ===
# {
#     "Type": "Job:Tableau",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "TABLEAU",
#     "Action": "Refresh Datasource",
#     "Datasource Name": "inventory_forecast"
# }
# {
#     "Type": "Job:Tableau",
#     "RunAs": "workbench",
#     "RunAsDummy": true,
#     "ConnectionProfile": "TABLEAU",
#     "Action": "Refresh Datasource",
#     "Datasource Name": "inventory_forecast"
# }

# %%
import json
import sys
from ctm_python_client.core.workflow import Workflow, WorkflowDefaults
from ctm_python_client.core.comm import Environment
from aapi import *

def dump_aapi_clean(job):
    """Return a standardized JSON string of the AAPI dump for reliable comparison."""
    return json.dumps(json.loads(job.dumps_aapi()), indent=4, sort_keys=True)

def compare_jobs(job1, job2, folder_name, job_index):
    """Compare two jobs' AAPI output and print differences, if any."""
    aapi1 = dump_aapi_clean(job1)
    aapi2 = dump_aapi_clean(job2)
    job_type = type(job1).__name__

    if aapi1 != aapi2:
        print(f"❌ MISMATCH in {folder_name} - Job {job_index} ({job_type})")
        print("---- Expected ----")
        print(aapi1)
        print("---- Actual ----")
        print(aapi2)
        return False
    else:
        print(f"✅ Match: {folder_name} - Job {job_index} ({job_type})")
        return True

def compare_folders(workflow1, workflow2, folder_name):
    """Compare all jobs in two folders with the same name."""
    jobs1 = workflow1._definitions[folder_name].job_list
    jobs2 = workflow2._definitions[folder_name].job_list

    if len(jobs1) != len(jobs2):
        print(f"❌ Job count mismatch in {folder_name}: {len(jobs1)} vs {len(jobs2)}")
        return False

    all_matched = True
    for i, (job1, job2) in enumerate(zip(jobs1, jobs2)):
        if not compare_jobs(job1, job2, folder_name, i):
            all_matched = False
    return all_matched

def run_tests():
    env = Environment.create_workbench('workbench')
    workflow_actual = Workflow.get_jobs(env, server="workbench", folder="Folder_Sanity_*")

    workflow = Workflow(env, WorkflowDefaults(run_as='workbench'))
    workflow.clear_all()
    run_as_dummy = True

    # Define jobs
    databricksLoad = JobDatabricks(
        'LoadForecasts',
        connection_profile='DATABRICKS',
        databricks_job_id='991955986358417',
        parameters='"params":{}',
        idempotency_token='tokeni_%%ORDERID',
        run_as_dummy=run_as_dummy
    )
    
    
    jobEvent = JobCommand('JobEvent', command='ls -lt')
    
    jobEvent.events_to_add.append(AddEvents([EventOutAdd(event="e2",date=Event.Date.NoDate)]))
    jobEvent.events_to_add.append(AddEvents([EventOutAdd(event="e3",date=Event.Date.NoDate)]))
    
    jobEvent.events_to_delete.append(DeleteEvents([Event(event="e5",date=Event.Date.NextOrderDate)]))
    jobEvent.events_to_delete.append(DeleteEvents([Event(event="e4",date=Event.Date.NextOrderDate)]))
    
    jobEvent.wait_for_events_list.append(WaitForEvents(["(",Event(event="e1"),"AND",Event(event="e2"), ")","OR", Event(event="e3", date=Event.Date.AnyDate)]))
    jobEvent.wait_for_events_list.append(WaitForEvents(["(",Event(event="e2"),"OR",Event(event="e4"), ")"]))


    sagemaker_job = JobAwsSageMaker(
        'InventoryForecastModel',
        connection_profile='SAGEMAKER',
        pipeline_name='InferencePipeline',
        idempotency_token='Token_ControlM_for_SageMaker%%ORDERID',
        add_parameters='checked',
        parameters='{"Name":"input_file", "Value": "file"}',
        run_as_dummy=run_as_dummy,
        retry_pipeline_execution='unchecked',
        rerun_limit=Job.RerunLimit(times='5')
    )

    tableau_refresh = JobTableau(
        'TableauRefresh',
        connection_profile='TABLEAU',
        action="Refresh Datasource",
        datasource_name="inventory_forecast",
        run_as_dummy=run_as_dummy
    )

    # Define folders
    folder1 = Folder('Folder_Sanity_1',
                     controlm_server='workbench',
                     job_list=[databricksLoad, jobEvent])

    folder2 = Folder('Folder_Sanity_2',
                     controlm_server='workbench',
                     job_list=[sagemaker_job, tableau_refresh])

    workflow.add(folder1)
    workflow.add(folder2)

    # Deploy workflow
    workflow.build()
    workflow.deploy()

    workflow_actual = Workflow.get_jobs(env, server="workbench", folder="Folder_Sanity_*")

    # Compare folders
    folders_to_test = ['Folder_Sanity_1', 'Folder_Sanity_2']
    all_passed = True
    for folder_name in folders_to_test:
        if not compare_folders(workflow, workflow_actual, folder_name):
            all_passed = False

    if not all_passed:
        print("❌ One or more job comparisons failed.")
        sys.exit(1)

    print("✅ All job comparisons passed.")

if __name__ == "__main__":
    run_tests()
# Out:
# ✅ Match: Folder_Sanity_1 - Job 0 (JobDatabricks)
# ❌ MISMATCH in Folder_Sanity_1 - Job 1 (JobCommand)
# ---- Expected ----
# {
#     "Command": "ls -lt",
#     "RunAs": "workbench",
#     "Type": "Job:Command",
#     "eventsToAdd_Hri1QZqL": {
#         "Events": [
#             {
#                 "Date": "NoDate",
#                 "Event": "e3"
#             }
#         ],
#         "Type": "AddEvents"
#     },
#     "eventsToAdd_fQNDTJKI": {
#         "Events": [
#             {
#                 "Date": "NoDate",
#                 "Event": "e2"
#             }
#         ],
#         "Type": "AddEvents"
#     },
#     "eventsToDelete_77h4uWr5": {
#         "Events": [
#             {
#                 "Date": "NextOrderDate",
#                 "Event": "e5"
#             }
#         ],
#         "Type": "DeleteEvents"
#     },
#     "eventsToDelete_EFbBBNdr": {
#         "Events": [
#             {
#                 "Date": "NextOrderDate",
#                 "Event": "e4"
#             }
#         ],
#         "Type": "DeleteEvents"
#     },
#     "waitForEvents_XiU7lrF2": {
#         "Events": [
#             "(",
#             {
#                 "Event": "e2"
#             },
#             "OR",
#             {
#                 "Event": "e4"
#             },
#             ")"
#         ],
#         "Type": "WaitForEvents"
#     },
#     "waitForEvents_Ye4k9NHf": {
#         "Events": [
#             "(",
#             {
#                 "Event": "e1"
#             },
#             "AND",
#             {
#                 "Event": "e2"
#             },
#             ")",
#             "OR",
#             {
#                 "Date": "AnyDate",
#                 "Event": "e3"
#             }
#         ],
#         "Type": "WaitForEvents"
#     }
# }
# ---- Actual ----
# {
#     "RunAs": "workbench",
#     "Type": "Job"
# }
# ✅ Match: Folder_Sanity_2 - Job 0 (JobAwsSageMaker)
# ✅ Match: Folder_Sanity_2 - Job 1 (JobTableau)
# ❌ One or more job comparisons failed.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# c:\projects\ctm-python-client\venv\Lib\site-packages\IPython\core\interactiveshell.py:3557: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import time as t
from ctm_python_client.core.workflow import Workflow, WorkflowDefaults
from ctm_python_client.core.comm import Environment
from aapi import *

workflow = Workflow(Environment.create_workbench('workbench'), WorkflowDefaults(run_as='workbench'))

workflow.clear_all()
run_as_dummy = True
jobEvent = JobCommand('JobEvent', command='ls -lt')

# Create the AddEvents container
add_events = AddEvents(events=[
    EventOutAdd(event="e2", date=Event.Date.NoDate),
    EventOutAdd(event="e3", date=Event.Date.NoDate)
])
jobEvent.events_to_add = add_events

delete_events = DeleteEvents(events=[
    Event(event="e5", date=Event.Date.NextOrderDate),
    Event(event="e4", date=Event.Date.NextOrderDate)
])
jobEvent.events_to_delete = delete_events

wait_events = WaitForEvents(events=[
    Event(event="e1"),
    Event(event="e2"),
    Event(event="e3", date=Event.Date.AnyDate)])

jobEvent.event_list = wait_events


folder1 = Folder('Folder_Sanity_y',
                 controlm_server='workbench',
                 job_list=[jobEvent])


workflow.add(folder1)

workflow.build()
workflow.deploy()

workflow2 = Workflow.get_jobs(Environment.create_workbench('workbench'), server="workbench", folder="Folder_Sanity_y")

print(workflow2)

# Folder_Sanity_1
print("=== Folder_Sanity_1 - Job 0 (databricksLoad) ===")
print(workflow._definitions['Folder_Sanity_y'].job_list[0].dumps_aapi(indent=4))
print(workflow2._definitions['Folder_Sanity_y'].job_list[0].dumps_aapi(indent=4))
# Out:
# Imported: aapi.action
# Imported: aapi.addevents
# Imported: aapi.ai
# Imported: aapi.basefolder
# Imported: aapi.bases
# Imported: aapi.businessfield
# Imported: aapi.businessparameter
# Imported: aapi.calendar
# Imported: aapi.calendarfields
# Imported: aapi.calendarkey
# Imported: aapi.captureoutput
# Imported: aapi.condition
# Imported: aapi.config
# Imported: aapi.connectionprofile
# Imported: aapi.ctbruledata
# Imported: aapi.date
# Imported: aapi.definitionitemdetails
# Imported: aapi.deleteevents
# Imported: aapi.disallowedoptions
# Imported: aapi.do
# Imported: aapi.donotify
# Imported: aapi.driver
# Imported: aapi.endpoint
# Imported: aapi.event
# Imported: aapi.extractrule
# Imported: aapi.filetransfer
# Imported: aapi.filetransfergroup
# Imported: aapi.flow_
# Imported: aapi.folderclientdata
# Imported: aapi.folderjobbase
# Imported: aapi.hostfiletransfer
# Imported: aapi.hostmapping
# Imported: aapi.if_
# Imported: aapi.ifbase
# Imported: aapi.ifcollection
# Imported: aapi.ifrerun
# Imported: aapi.integration_factory
# Imported: aapi.integration_factory.connection_profiles
# Imported: aapi.integration_factory.jobs
# Imported: aapi.internalrule
# Imported: aapi.iteminfo
# Imported: aapi.job
# Imported: aapi.jobsfilter
# Imported: aapi.jobtag
# Imported: aapi.mail
# Imported: aapi.notify
# Imported: aapi.on
# Imported: aapi.output
# Imported: aapi.package
# Imported: aapi.packageparams
# Imported: aapi.period
# Imported: aapi.possibleoptions
# Imported: aapi.propertycondition
# Imported: aapi.rbcdetails
# Imported: aapi.remedy
# Imported: aapi.resource
# Imported: aapi.resourcepools
# Imported: aapi.run
# Imported: aapi.runningjobs
# Imported: aapi.set_
# Imported: aapi.sitestandard
# Imported: aapi.sitestandarddata
# Imported: aapi.sitestandardoperatorvalueoptions
# Imported: aapi.sitestandardpolicy
# Imported: aapi.sitestandardpolicydata
# Imported: aapi.sitestandardpossiblevalue
# Imported: aapi.sitestandardrestriction
# Imported: aapi.steprange
# Imported: aapi.tag
# Imported: aapi.time
# Imported: aapi.variable
# Imported: aapi.waitforevents
# Imported: aapi.workloadflat
# Imported: aapi.workloadpolicy
# Imported: aapi.wpperiod
# Imported: aapi.year
# Discovered class: AAPIJob
# Discovered class: AAPIObject
# Discovered class: AIConnectionProfile
# Discovered class: AIJob
# Discovered class: Job.DocumentationFile
# Discovered class: Job.DocumentationUrl
# Discovered class: Job.Output
# Discovered class: Job.PathElement
# Discovered class: Job.Rerun
# Discovered class: Job.RerunIntervals
# Discovered class: Job.RerunLimit
# Discovered class: Job.RerunSpecificTimes
# Discovered class: Job.When
# Discovered class: Job.When.ConfirmationCalendars
# Discovered class: Job.When.RuleBasedCalendars
# Discovered class: Action
# Discovered class: ActionCaptureOutput
# Discovered class: ActionCaptureOutput.ForwardBy
# Discovered class: ActionControlMAnalyzerRule
# Discovered class: ActionMail
# Discovered class: ActionNotify
# Discovered class: ActionOutput
# Discovered class: ActionRemedy
# Discovered class: ActionRerun
# Discovered class: ActionRestart
# Discovered class: ActionRun
# Discovered class: ActionSet
# Discovered class: ActionSetToNotOK
# Discovered class: ActionSetToOK
# Discovered class: ActionStopCyclicRun
# Discovered class: AddEvents
# Discovered class: BusinessField
# Discovered class: BusinessParameter
# Discovered class: BusinessParameter.Characters
# Discovered class: BusinessParameter.Characters.Alphanumeric
# Discovered class: BusinessParameter.Characters.Any
# Discovered class: BusinessParameter.Exclude
# Discovered class: BusinessParameter.Include
# Discovered class: Calendar
# Discovered class: CalendarFields
# Discovered class: CalendarFieldsPeriodic
# Discovered class: CalendarFieldsRegular
# Discovered class: CalendarFieldsRuleBased
# Discovered class: CalendarKey
# Discovered class: CalendarKeyPeriodic
# Discovered class: CalendarKeyRegular
# Discovered class: CalendarKeyRuleBased
# Discovered class: CalendarPeriodic
# Discovered class: CalendarPeriodic.When
# Discovered class: CalendarRegular
# Discovered class: CalendarRegular.When
# Discovered class: CalendarRuleBased
# Discovered class: CalendarRuleBased.When
# Discovered class: CalendarRuleBased.When.ConfirmationCalendars
# Discovered class: CalendarRuleBasedCalendar
# Discovered class: CalendarRuleBasedCalendar.When
# Discovered class: CalendarRuleBasedCalendar.When.ConfirmationCalendars
# Discovered class: Condition
# Discovered class: ConditionIn
# Discovered class: ConditionOut
# Discovered class: ConditionOutAdd
# Discovered class: ConditionOutDelete
# Discovered class: Config
# Discovered class: ConfigHadoop
# Discovered class: ConnectionProfile
# Discovered class: ConnectionProfileAWS
# Discovered class: ConnectionProfileAWS.ProxySettings
# Discovered class: ConnectionProfileAirbyte
# Discovered class: ConnectionProfileAirflow
# Discovered class: ConnectionProfileAirflowGoogleComposer
# Discovered class: ConnectionProfileAirflowStandalone
# Discovered class: ConnectionProfileAlteryxTrifacta
# Discovered class: ConnectionProfileAnsibleAWX
# Discovered class: ConnectionProfileApacheAirflow
# Discovered class: ConnectionProfileApacheNiFi
# Discovered class: ConnectionProfileAstronomer
# Discovered class: ConnectionProfileAutomationAnywhere
# Discovered class: ConnectionProfileAwsAppFlow
# Discovered class: ConnectionProfileAwsAppRunner
# Discovered class: ConnectionProfileAwsAthena
# Discovered class: ConnectionProfileAwsBackup
# Discovered class: ConnectionProfileAwsBatch
# Discovered class: ConnectionProfileAwsCloudFormation
# Discovered class: ConnectionProfileAwsDataPipeline
# Discovered class: ConnectionProfileAwsDataSync
# Discovered class: ConnectionProfileAwsDynamoDB
# Discovered class: ConnectionProfileAwsEC2
# Discovered class: ConnectionProfileAwsECS
# Discovered class: ConnectionProfileAwsEMR
# Discovered class: ConnectionProfileAwsGlue
# Discovered class: ConnectionProfileAwsGlueDataBrew
# Discovered class: ConnectionProfileAwsLambda
# Discovered class: ConnectionProfileAwsMWAA
# Discovered class: ConnectionProfileAwsMainframeModernization
# Discovered class: ConnectionProfileAwsQuickSight
# Discovered class: ConnectionProfileAwsRedshift
# Discovered class: ConnectionProfileAwsSNS
# Discovered class: ConnectionProfileAwsSQS
# Discovered class: ConnectionProfileAwsSageMaker
# Discovered class: ConnectionProfileAwsStepFunctions
# Discovered class: ConnectionProfileAzure
# Discovered class: ConnectionProfileAzure.Batch
# Discovered class: ConnectionProfileAzureBackup
# Discovered class: ConnectionProfileAzureBatchAccounts
# Discovered class: ConnectionProfileAzureDataFactory
# Discovered class: ConnectionProfileAzureDatabricks
# Discovered class: ConnectionProfileAzureDevOps
# Discovered class: ConnectionProfileAzureFunctions
# Discovered class: ConnectionProfileAzureHDInsight
# Discovered class: ConnectionProfileAzureLogicApps
# Discovered class: ConnectionProfileAzureMachineLearning
# Discovered class: ConnectionProfileAzureResourceManager
# Discovered class: ConnectionProfileAzureServiceBus
# Discovered class: ConnectionProfileAzureSynapse
# Discovered class: ConnectionProfileAzureVM
# Discovered class: ConnectionProfileBoomiAtomsphere
# Discovered class: ConnectionProfileCircleCI
# Discovered class: ConnectionProfileCommunicationSuite
# Discovered class: ConnectionProfileDBT
# Discovered class: ConnectionProfileDatabase
# Discovered class: ConnectionProfileDatabaseDB2
# Discovered class: ConnectionProfileDatabaseJDBC
# Discovered class: ConnectionProfileDatabaseMSSql
# Discovered class: ConnectionProfileDatabaseMSSqlSSIS
# Discovered class: ConnectionProfileDatabaseOracle
# Discovered class: ConnectionProfileDatabaseOracleConnectionString
# Discovered class: ConnectionProfileDatabaseOracleSID
# Discovered class: ConnectionProfileDatabaseOracleServiceName
# Discovered class: ConnectionProfileDatabasePostgreSql
# Discovered class: ConnectionProfileDatabaseSybase
# Discovered class: ConnectionProfileDatabricks
# Discovered class: ConnectionProfileFileTransfer
# Discovered class: ConnectionProfileFileTransferAS2
# Discovered class: ConnectionProfileFileTransferAS2.EncryptMessageParameters
# Discovered class: ConnectionProfileFileTransferAS2.RequestReceiptParameters
# Discovered class: ConnectionProfileFileTransferAS2.SignMessageParameters
# Discovered class: ConnectionProfileFileTransferAzure
# Discovered class: ConnectionProfileFileTransferAzureAdCertificate
# Discovered class: ConnectionProfileFileTransferAzureAdClientSecret
# Discovered class: ConnectionProfileFileTransferAzureAdUserPass
# Discovered class: ConnectionProfileFileTransferAzureConnectionString
# Discovered class: ConnectionProfileFileTransferAzureManagedIdentity
# Discovered class: ConnectionProfileFileTransferAzureSharedAccessSignature
# Discovered class: ConnectionProfileFileTransferAzureSharedKey
# Discovered class: ConnectionProfileFileTransferDualEndPoint
# Discovered class: ConnectionProfileFileTransferFTP
# Discovered class: ConnectionProfileFileTransferFTPS
# Discovered class: ConnectionProfileFileTransferGcs
# Discovered class: ConnectionProfileFileTransferGroup
# Discovered class: ConnectionProfileFileTransferLocal
# Discovered class: ConnectionProfileFileTransferS3
# Discovered class: ConnectionProfileFileTransferS3Amazon
# Discovered class: ConnectionProfileFileTransferS3Compatible
# Discovered class: ConnectionProfileFileTransferSFTP
# Discovered class: ConnectionProfileGCPBatch
# Discovered class: ConnectionProfileGCPBigQuery
# Discovered class: ConnectionProfileGCPCloudRun
# Discovered class: ConnectionProfileGCPComposer
# Discovered class: ConnectionProfileGCPDataFusion
# Discovered class: ConnectionProfileGCPDataflow
# Discovered class: ConnectionProfileGCPDataplex
# Discovered class: ConnectionProfileGCPDataprep
# Discovered class: ConnectionProfileGCPDataproc
# Discovered class: ConnectionProfileGCPDeploymentManager
# Discovered class: ConnectionProfileGCPFunctions
# Discovered class: ConnectionProfileGCPVM
# Discovered class: ConnectionProfileGCPWorkflows
# Discovered class: ConnectionProfileHadoop
# Discovered class: ConnectionProfileHadoop.Hive
# Discovered class: ConnectionProfileHadoop.Oozie
# Discovered class: ConnectionProfileHadoop.Spark
# Discovered class: ConnectionProfileHadoop.Sqoop
# Discovered class: ConnectionProfileHadoop.Tajo
# Discovered class: ConnectionProfileIBMDataStageLinux
# Discovered class: ConnectionProfileIBMDataStageWindows
# Discovered class: ConnectionProfileInformatica
# Discovered class: ConnectionProfileInformaticaCS
# Discovered class: ConnectionProfileJenkins
# Discovered class: ConnectionProfileKubernetes
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationAws
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationAws.AuthMethodAccessAndSecretKeys
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationAws.AuthMethodIAMRole
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationBasic
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationGoogle
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationOauth2
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationOauth2.BasicAuthentication
# Discovered class: ConnectionProfileKubernetes.WebServiceAuthenticationOauth2.GrantTypePassword
# Discovered class: ConnectionProfileMicroFocusLinux
# Discovered class: ConnectionProfileMicroFocusWindows
# Discovered class: ConnectionProfileMicrosoftPowerBI
# Discovered class: ConnectionProfileMicrosoftPowerBISP
# Discovered class: ConnectionProfileNetBackup
# Discovered class: ConnectionProfileOCIDataFlow
# Discovered class: ConnectionProfileOCIDataIntegration
# Discovered class: ConnectionProfileOCIDataScience
# Discovered class: ConnectionProfileOCIVM
# Discovered class: ConnectionProfilePagerDuty
# Discovered class: ConnectionProfilePeopleSoft
# Discovered class: ConnectionProfileQlikCloud
# Discovered class: ConnectionProfileRabbitMQ
# Discovered class: ConnectionProfileSAP
# Discovered class: ConnectionProfileSAP.ApplicationServerLogon
# Discovered class: ConnectionProfileSAP.GroupLogon
# Discovered class: ConnectionProfileSAP.SecuredNetworkConnection
# Discovered class: ConnectionProfileSnowflake
# Discovered class: ConnectionProfileSnowflakeIdP
# Discovered class: ConnectionProfileTableau
# Discovered class: ConnectionProfileTalendDataManagement
# Discovered class: ConnectionProfileTalendOAuth
# Discovered class: ConnectionProfileTerraform
# Discovered class: ConnectionProfileUIPath
# Discovered class: ConnectionProfileVMwareByBroadcom
# Discovered class: ConnectionProfileVeritasNetBackup
# Discovered class: ConnectionProfileWSCONFIG
# Discovered class: ConnectionProfileWebServices
# Discovered class: ConnectionProfileWebServicesREST
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationAws
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationAws.AuthMethodAccessAndSecretKeys
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationAws.AuthMethodIAMRole
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationBasic
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationGoogle
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationOauth2
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationOauth2.BasicAuthentication
# Discovered class: ConnectionProfileWebServicesREST.WebServiceAuthenticationOauth2.GrantTypePassword
# Discovered class: ConnectionProfileWebServicesSOAP
# Discovered class: ConnectionProfileWebServicesSOAP.WebServiceAuthenticationBasic
# Discovered class: Date
# Discovered class: DefinitionItemDetails
# Discovered class: DeleteEvents
# Discovered class: DisallowedOptions
# Discovered class: Do
# Discovered class: DriverJdbcDatabase
# Discovered class: Endpoint
# Discovered class: EndpointDest
# Discovered class: EndpointDestFtp
# Discovered class: EndpointDestFtps
# Discovered class: EndpointDestLocal
# Discovered class: EndpointDestSftp
# Discovered class: EndpointSrc
# Discovered class: EndpointSrcFtp
# Discovered class: EndpointSrcFtps
# Discovered class: EndpointSrcLocal
# Discovered class: EndpointSrcSftp
# Discovered class: Event
# Discovered class: EventAdd
# Discovered class: EventDelete
# Discovered class: EventIn
# Discovered class: EventOut
# Discovered class: EventOutAdd
# Discovered class: EventOutDelete
# Discovered class: ExtractRule
# Discovered class: FileTransfer
# Discovered class: FileTransfer.FileWatcherOptions
# Discovered class: FileTransfer.PostCommandDest
# Discovered class: FileTransfer.PostCommandSrc
# Discovered class: FileTransfer.PreCommandDest
# Discovered class: FileTransfer.PreCommandSrc
# Discovered class: FileTransferGroup
# Discovered class: Flow_
# Discovered class: Folder
# Discovered class: Folder.DocumentationFile
# Discovered class: Folder.DocumentationUrl
# Discovered class: Folder.MustEnd
# Discovered class: Folder.Rerun
# Discovered class: Folder.RerunIntervals
# Discovered class: Folder.RerunLimit
# Discovered class: Folder.RerunSpecificTimes
# Discovered class: Folder.When
# Discovered class: Folder.When.RuleBasedCalendars
# Discovered class: FolderClientData
# Discovered class: FolderJobBase
# Discovered class: FolderJobBase.DocumentationFile
# Discovered class: FolderJobBase.DocumentationUrl
# Discovered class: FolderJobBaseSmart
# Discovered class: FolderJobBaseSmart.Rerun
# Discovered class: FolderJobBaseSmart.RerunIntervals
# Discovered class: FolderJobBaseSmart.RerunSpecificTimes
# Discovered class: HostFileTransfer
# Discovered class: HostMapping
# Discovered class: IfBase
# Discovered class: IfBaseFolder
# Discovered class: IfCollection
# Discovered class: IfCollectionZOS
# Discovered class: IfCompletionStatus
# Discovered class: IfJobNotSubmitted
# Discovered class: IfJobOutputNotFound
# Discovered class: IfNumberOfExecutions
# Discovered class: IfNumberOfFailures
# Discovered class: IfNumberOfReruns
# Discovered class: IfOutput
# Discovered class: IfVariableValue
# Discovered class: IfVariableValue.RangeVariableValue
# Discovered class: InternalRule
# Discovered class: InternalRule.Characters
# Discovered class: InternalRule.Characters.Alphanumeric
# Discovered class: InternalRule.Characters.Any
# Discovered class: InternalRule.Exclude
# Discovered class: InternalRule.Include
# Discovered class: ItemInfo
# Discovered class: Job
# Discovered class: JobAWS
# Discovered class: JobAWSBatch
# Discovered class: JobAWSBatch.DependsOn
# Discovered class: JobAWSLambda
# Discovered class: JobAWSStepFunction
# Discovered class: JobAirbyte
# Discovered class: JobAirflow
# Discovered class: JobAlteryxTrifacta
# Discovered class: JobAnsibleAWX
# Discovered class: JobApacheAirflow
# Discovered class: JobApacheNiFi
# Discovered class: JobAstronomer
# Discovered class: JobAutomationAnywhere
# Discovered class: JobAwsAppFlow
# Discovered class: JobAwsAppRunner
# Discovered class: JobAwsAthena
# Discovered class: JobAwsBackup
# Discovered class: JobAwsBatch
# Discovered class: JobAwsCloudFormation
# Discovered class: JobAwsDataPipeline
# Discovered class: JobAwsDataSync
# Discovered class: JobAwsDynamoDB
# Discovered class: JobAwsEC2
# Discovered class: JobAwsECS
# Discovered class: JobAwsEMR
# Discovered class: JobAwsGlue
# Discovered class: JobAwsGlueDataBrew
# Discovered class: JobAwsLambda
# Discovered class: JobAwsMWAA
# Discovered class: JobAwsMainframeModernization
# Discovered class: JobAwsQuickSight
# Discovered class: JobAwsRedshift
# Discovered class: JobAwsSNS
# Discovered class: JobAwsSQS
# Discovered class: JobAwsSageMaker
# Discovered class: JobAwsStepFunctions
# Discovered class: JobAzure
# Discovered class: JobAzureBackup
# Discovered class: JobAzureBatchAccount
# Discovered class: JobAzureBatchAccount.MaxTries
# Discovered class: JobAzureBatchAccount.Retention
# Discovered class: JobAzureBatchAccount.Wallclock
# Discovered class: JobAzureBatchAccounts
# Discovered class: JobAzureDataFactory
# Discovered class: JobAzureDatabricks
# Discovered class: JobAzureDevOps
# Discovered class: JobAzureFunction
# Discovered class: JobAzureFunctions
# Discovered class: JobAzureHDInsight
# Discovered class: JobAzureLogicApps
# Discovered class: JobAzureMachineLearning
# Discovered class: JobAzureResourceManager
# Discovered class: JobAzureServiceBus
# Discovered class: JobAzureSynapse
# Discovered class: JobAzureVM
# Discovered class: JobBoomiAtomsphere
# Discovered class: JobCircleCI
# Discovered class: JobCommand
# Discovered class: JobCommunicationSuite
# Discovered class: JobDBT
# Discovered class: JobDatabase
# Discovered class: JobDatabaseEmbeddedQuery
# Discovered class: JobDatabaseMSSQLAgentJob
# Discovered class: JobDatabaseMSSQL_SSIS
# Discovered class: JobDatabaseSQLScript
# Discovered class: JobDatabaseStoredProcedure
# Discovered class: JobDatabricks
# Discovered class: JobDummy
# Discovered class: JobEmbeddedScript
# Discovered class: JobFileTransfer
# Discovered class: JobFileWatcher
# Discovered class: JobFileWatcherCreate
# Discovered class: JobFileWatcherDelete
# Discovered class: JobGCPBatch
# Discovered class: JobGCPBigQuery
# Discovered class: JobGCPCloudRun
# Discovered class: JobGCPComposer
# Discovered class: JobGCPDataFusion
# Discovered class: JobGCPDataflow
# Discovered class: JobGCPDataplex
# Discovered class: JobGCPDataprep
# Discovered class: JobGCPDataproc
# Discovered class: JobGCPDeploymentManager
# Discovered class: JobGCPFunctions
# Discovered class: JobGCPVM
# Discovered class: JobGCPWorkflows
# Discovered class: JobHadoop
# Discovered class: JobHadoop.PostCommands
# Discovered class: JobHadoop.PreCommands
# Discovered class: JobHadoopDistCp
# Discovered class: JobHadoopHDFSCommands
# Discovered class: JobHadoopHDFSFileWatcher
# Discovered class: JobHadoopHive
# Discovered class: JobHadoopMapReduce
# Discovered class: JobHadoopMapredStreaming
# Discovered class: JobHadoopOozie
# Discovered class: JobHadoopPig
# Discovered class: JobHadoopSpark
# Discovered class: JobHadoopSparkPython
# Discovered class: JobHadoopSparkScalaJava
# Discovered class: JobHadoopSqoop
# Discovered class: JobHadoopTajo
# Discovered class: JobHadoopTajoInputFile
# Discovered class: JobHadoopTajoQuery
# Discovered class: JobIBMCognos
# Discovered class: JobIBMDataStage
# Discovered class: JobIBMDataStageLinux
# Discovered class: JobIBMDataStageWindows
# Discovered class: JobInformatica
# Discovered class: JobInformaticaCS
# Discovered class: JobJava
# Discovered class: JobJenkins
# Discovered class: JobKubernetes
# Discovered class: JobKubernetes.WsRestBody
# Discovered class: JobMessaging
# Discovered class: JobMessagingFreeText
# Discovered class: JobMessagingPreDefined
# Discovered class: JobMessagingWaitForReply
# Discovered class: JobMicroFocusLinux
# Discovered class: JobMicroFocusWindows
# Discovered class: JobMicrosoftPowerBI
# Discovered class: JobMicrosoftPowerBISP
# Discovered class: JobNetBackup
# Discovered class: JobOCIDataFlow
# Discovered class: JobOCIDataIntegration
# Discovered class: JobOCIDataScience
# Discovered class: JobOCIVM
# Discovered class: JobOEBS
# Discovered class: JobOEBS.RequestSet
# Discovered class: JobOEBS.SingleRequest
# Discovered class: JobOS400
# Discovered class: JobOS400ExternalJob
# Discovered class: JobOS400ExternalSubSystem
# Discovered class: JobOS400Full
# Discovered class: JobOS400FullCommandLine
# Discovered class: JobOS400FullDescriptionJob
# Discovered class: JobOS400FullExternalJob
# Discovered class: JobOS400FullExternalSubSystem
# Discovered class: JobOS400FullMultipleCommands
# Discovered class: JobOS400FullProgram
# Discovered class: JobOS400FullRestrictedStateAction
# Discovered class: JobOS400FullScriptFile
# Discovered class: JobOS400FullScriptFile.EmbeddedScriptFileLocation
# Discovered class: JobOS400FullScriptFile.IFSScriptFileLocation
# Discovered class: JobOS400FullScriptFile.NativeScriptFileLocation
# Discovered class: JobOS400FullSubSystem
# Discovered class: JobOS400FullVirtualTerminal
# Discovered class: JobOS400FullVirtualTerminal.EmbeddedScriptFileLocation
# Discovered class: JobOS400FullVirtualTerminal.IFSScriptFileLocation
# Discovered class: JobOS400FullVirtualTerminal.NativeScriptFileLocation
# Discovered class: JobOS400MultipleCommands
# Discovered class: JobOS400Program
# Discovered class: JobOS400VirtualTerminal
# Discovered class: JobOS400VirtualTerminal.EmbeddedScriptFileLocation
# Discovered class: JobOS400VirtualTerminal.IFSScriptFileLocation
# Discovered class: JobOS400VirtualTerminal.NativeScriptFileLocation
# Discovered class: JobPagerDuty
# Discovered class: JobPeopleSoft
# Discovered class: JobQlikCloud
# Discovered class: JobRabbitMQ
# Discovered class: JobSAP
# Discovered class: JobSAPBW
# Discovered class: JobSAPBW.DetectSpawnedJob
# Discovered class: JobSAPBWInfoPackage
# Discovered class: JobSAPBWInfoPackage.InfoPackage
# Discovered class: JobSAPBWProcessChain
# Discovered class: JobSAPDataArchiving
# Discovered class: JobSAPDataArchivingDelete
# Discovered class: JobSAPDataArchivingStore
# Discovered class: JobSAPDataArchivingWrite
# Discovered class: JobSAPDataArchivingWrite.DetectSpawnedJob
# Discovered class: JobSAPDataArchivingWrite.Validations
# Discovered class: JobSAPDataArchivingWrite.Variant
# Discovered class: JobSAPR3
# Discovered class: JobSAPR3BatchInputSession
# Discovered class: JobSAPR3BatchInputSession.Pattern
# Discovered class: JobSAPR3BatchInputSession.Session
# Discovered class: JobSAPR3COPY
# Discovered class: JobSAPR3COPY.DetectSpawnedJob
# Discovered class: JobSAPR3COPY.PostJobAction
# Discovered class: JobSAPR3CREATE
# Discovered class: JobSAPR3CREATE.DetectSpawnedJob
# Discovered class: JobSAPR3CREATE.PostJobAction
# Discovered class: JobSAPR3CREATE.SpoolListRecipient
# Discovered class: JobSAPR3MonitorSapJob
# Discovered class: JobSAPR3MonitorSapJob.DetectSpawnedJob
# Discovered class: JobSAPR3PredefinedSapJob
# Discovered class: JobSAPR3PredefinedSapJob.DetectSpawnedJob
# Discovered class: JobSAPR3PredefinedSapJob.PostJobAction
# Discovered class: JobSAPR3SapProfile
# Discovered class: JobSAPR3SapProfileActivate
# Discovered class: JobSAPR3SapProfileActivate.ProfileInformation
# Discovered class: JobSAPR3SapProfileDeactivate
# Discovered class: JobSAPR3SapProfileDeactivate.ProfileInformation
# Discovered class: JobSAPR3TriggerSapEvent
# Discovered class: JobSAPR3WatchSapEvent
# Discovered class: JobSLAManagement
# Discovered class: JobSLAManagement.AverageRunTimeTolerance
# Discovered class: JobSLAManagement.CompleteBy
# Discovered class: JobSLAManagement.CompleteIn
# Discovered class: JobScript
# Discovered class: JobSnowflake
# Discovered class: JobSnowflakeIdP
# Discovered class: JobTableau
# Discovered class: JobTag
# Discovered class: JobTalendDataManagement
# Discovered class: JobTalendOAuth
# Discovered class: JobTandem
# Discovered class: JobTandemCommand
# Discovered class: JobTandemEmbeddedTACLScript
# Discovered class: JobTandemExternalProcess
# Discovered class: JobTandemExternalProcess.ExternalCPUPIN
# Discovered class: JobTandemExternalProcess.ExternalProcessId
# Discovered class: JobTandemProgram
# Discovered class: JobTandemTACLScript
# Discovered class: JobTerraform
# Discovered class: JobUIPath
# Discovered class: JobVMware
# Discovered class: JobVMwareByBroadcom
# Discovered class: JobVMwareConfiguration
# Discovered class: JobVMwareConfigurationCloneVirtualMachine
# Discovered class: JobVMwareConfigurationDeployTemplate
# Discovered class: JobVMwareConfigurationMigrateVirtualMachine
# Discovered class: JobVMwareConfigurationReconfigureVirtualMachine
# Discovered class: JobVMwarePower
# Discovered class: JobVMwarePowerOff
# Discovered class: JobVMwarePowerOn
# Discovered class: JobVMwarePowerReboot
# Discovered class: JobVMwarePowerReset
# Discovered class: JobVMwarePowerShutdown
# Discovered class: JobVMwarePowerStandby
# Discovered class: JobVMwarePowerSuspend
# Discovered class: JobVMwareSnapshot
# Discovered class: JobVMwareSnapshotRemove
# Discovered class: JobVMwareSnapshotRemoveAll
# Discovered class: JobVMwareSnapshotRevert
# Discovered class: JobVMwareSnapshotRevertToCurrent
# Discovered class: JobVMwareSnapshotTake
# Discovered class: JobVeritasNetBackup
# Discovered class: JobWebServices
# Discovered class: JobWebServicesREST
# Discovered class: JobWebServicesREST.WsRestBody
# Discovered class: JobWebServicesSOAP
# Discovered class: JobWebServicesSOAP.SoapRequest
# Discovered class: JobZOS
# Discovered class: JobZOS.Archiving
# Discovered class: JobZOS.History
# Discovered class: JobZOS.MustEnd
# Discovered class: JobZOS.OutputHandling
# Discovered class: JobZOS.Scheduling
# Discovered class: JobZOS.TaskInformation
# Discovered class: JobZOSInStreamJCL
# Discovered class: JobZOSMember
# Discovered class: JobsFilter
# Discovered class: Notify
# Discovered class: NotifyDoesNotEnd
# Discovered class: NotifyDoesNotStart
# Discovered class: NotifyExecutionTime
# Discovered class: NotifyLateCyclicSubmit
# Discovered class: NotifyNotOK
# Discovered class: NotifyOK
# Discovered class: NotifyRerun
# Discovered class: On
# Discovered class: Package
# Discovered class: PackageParams
# Discovered class: Period
# Discovered class: PossibleOptions
# Discovered class: PropertyCondition
# Discovered class: RbcDetails
# Discovered class: Resource
# Discovered class: ResourceLock
# Discovered class: ResourcePool
# Discovered class: ResourcePools
# Discovered class: ResourcePools.DatesList
# Discovered class: ResourcePools.PeriodicDays
# Discovered class: ResourcePools.RangeDates
# Discovered class: ResourcePools.RangeDatesWithTimes
# Discovered class: ResourcePools.SpecificTime
# Discovered class: ResourcePools.Time
# Discovered class: ResourcePools.WeekDaysRange
# Discovered class: RunningJobs
# Discovered class: RunningJobs.DatesList
# Discovered class: RunningJobs.PeriodicDays
# Discovered class: RunningJobs.RangeDates
# Discovered class: RunningJobs.RangeDatesWithTimes
# Discovered class: RunningJobs.SpecificTime
# Discovered class: RunningJobs.Time
# Discovered class: RunningJobs.WeekDaysRange
# Discovered class: SimpleFolder
# Discovered class: SiteStandard
# Discovered class: SiteStandardData
# Discovered class: SiteStandardOperatorValueOptions
# Discovered class: SiteStandardPolicy
# Discovered class: SiteStandardPolicy.ApplyOn
# Discovered class: SiteStandardPolicyData
# Discovered class: SiteStandardPossibleValue
# Discovered class: SiteStandardRestriction
# Discovered class: SiteStandardRestrictionEnum
# Discovered class: SiteStandardRestrictionNumeric
# Discovered class: SiteStandardRestrictionOperatorValue
# Discovered class: SiteStandardRestrictionText
# Discovered class: StepRange
# Discovered class: SubFolder
# Discovered class: SubFolder.PathElement
# Discovered class: SubFolder.When
# Discovered class: SubFolder.When.RuleBasedCalendars
# Discovered class: Tag
# Discovered class: TagFolder
# Discovered class: TagGlobal
# Discovered class: Time
# Discovered class: Variable
# Discovered class: WaitForEvents
# Discovered class: WorkloadFlat
# Discovered class: WorkloadPolicy
# Discovered class: WorkloadPolicy.Filter
# Discovered class: WpPeriod
# Discovered class: Year
# Discovered class: IfZOS
# Discovered class: IfZOSAnyProgramStep
# Discovered class: IfZOSEveryProgramStep
# Discovered class: IfZOSJOBRCCodes
# Discovered class: IfZOSNumberOfFailures
# Discovered class: IfZOSOutputPattern
# Discovered class: IfZOSSpecificProgramStep
# Discovered class: IfZOSSpecificRangeName
# Discovered class: JobAzureLogicApps
# Discovered class: JobNetBackup
# Registering structure hook for: Job
# Registering structure hook for: JobSAPR3MonitorSapJob.DetectSpawnedJob
# Registering structure hook for: JobWebServicesSOAP
# Registering structure hook for: ConnectionProfileAirbyte
# Registering structure hook for: ConnectionProfileAwsBatch
# Registering structure hook for: ConnectionProfileFileTransferAS2
# Registering structure hook for: JobAzureServiceBus
# Registering structure hook for: JobGCPDataplex
# Registering structure hook for: JobSAPR3MonitorSapJob
# Registering structure hook for: FolderJobBase.DocumentationUrl
# Registering structure hook for: ConnectionProfileGCPVM
# Registering structure hook for: JobPagerDuty
# Registering structure hook for: JobHadoopPig
# Registering structure hook for: ConnectionProfileFileTransferAzureSharedKey
# Registering structure hook for: ConnectionProfileDatabricks
# Registering structure hook for: JobSnowflake
# Registering structure hook for: JobAzureSynapse
# Registering structure hook for: FolderJobBaseSmart
# Registering structure hook for: SubFolder.When.RuleBasedCalendars
# Registering structure hook for: JobUIPath
# Registering structure hook for: JobQlikCloud
# Registering structure hook for: JobVMwarePowerOn
# Registering structure hook for: JobDatabase
# Registering structure hook for: JobZOSInStreamJCL
# Registering structure hook for: JobOS400ExternalSubSystem
# Registering structure hook for: JobMessagingPreDefined
# Registering structure hook for: ConnectionProfileAwsSageMaker
# Registering structure hook for: JobCommand
# Registering structure hook for: Notify
# Registering structure hook for: Folder.RerunIntervals
# Registering structure hook for: JobAzureLogicApps
# Registering structure hook for: JobOS400FullScriptFile
# Registering structure hook for: ConnectionProfileAwsMainframeModernization
# Registering structure hook for: CalendarPeriodic.When
# Registering structure hook for: JobOS400FullScriptFile.IFSScriptFileLocation
# Registering structure hook for: JobTalendDataManagement
# Registering structure hook for: CalendarFieldsPeriodic
# Registering structure hook for: ConnectionProfileAzureDataFactory
# Registering structure hook for: Folder.DocumentationUrl
# Registering structure hook for: JobVMwareSnapshotRevert
# Registering structure hook for: TagGlobal
# Registering structure hook for: JobOS400FullExternalSubSystem
# Registering structure hook for: SubFolder.When
# Registering structure hook for: JobSAPR3
# Registering structure hook for: JobMicroFocusLinux
# Registering structure hook for: ConnectionProfileDatabaseOracleSID
# Registering structure hook for: JobGCPCloudRun
# Registering structure hook for: JobDatabaseMSSQL_SSIS
# Registering structure hook for: AAPIJob
# Registering structure hook for: Job.PathElement
# Registering structure hook for: ConnectionProfileAwsLambda
# Registering structure hook for: IfNumberOfReruns
# Registering structure hook for: ConnectionProfileGCPDataprep
# Registering structure hook for: CalendarRuleBasedCalendar
# Registering structure hook for: EndpointSrcFtp
# Registering structure hook for: On
# Registering structure hook for: JobSAPR3BatchInputSession
# Registering structure hook for: ConnectionProfileAwsEC2
# Registering structure hook for: EndpointDest
# Registering structure hook for: JobOS400FullCommandLine
# Registering structure hook for: ConnectionProfileGCPDataFusion
# Registering structure hook for: Folder.MustEnd
# Registering structure hook for: ConnectionProfileKubernetes.WebServiceAuthenticationOauth2
# Registering structure hook for: ActionMail
# Registering structure hook for: JobAzureDevOps
# Registering structure hook for: ActionOutput
# Registering structure hook for: JobFileTransfer
# Registering structure hook for: ConnectionProfileApacheNiFi
# Registering structure hook for: BusinessParameter
# Registering structure hook for: JobGCPDataproc
# Registering structure hook for: ConnectionProfileAwsSQS
# Registering structure hook for: ConnectionProfileHadoop.Spark
# Registering structure hook for: JobMicroFocusWindows
# Registering structure hook for: Tag
# Registering structure hook for: JobHadoopSpark
# Registering structure hook for: JobSAPDataArchivingStore
# Registering structure hook for: JobZOS.Archiving
# Registering structure hook for: ResourcePool
# Registering structure hook for: Folder.RerunSpecificTimes
# Registering structure hook for: JobHadoopMapredStreaming
# Registering structure hook for: JobSAPDataArchiving
# Registering structure hook for: ConnectionProfileFileTransferDualEndPoint
# Registering structure hook for: EventOutDelete
# Registering structure hook for: ConnectionProfileAzure.Batch
# Registering structure hook for: ActionSet
# Registering structure hook for: ConnectionProfileAwsDataSync
# Registering structure hook for: DriverJdbcDatabase
# Registering structure hook for: IfJobNotSubmitted
# Registering structure hook for: JobAwsCloudFormation
# Registering structure hook for: ConnectionProfileDatabaseOracleConnectionString
# Registering structure hook for: ConnectionProfileWebServicesREST.WebServiceAuthenticationGoogle
# Registering structure hook for: SiteStandardRestrictionText
# Registering structure hook for: Config
# Registering structure hook for: JobAzureResourceManager
# Registering structure hook for: JobZOS
# Registering structure hook for: JobSAPR3COPY
# Registering structure hook for: JobHadoop
# Registering structure hook for: JobSLAManagement.CompleteIn
# Registering structure hook for: ConnectionProfileAWS.ProxySettings
# Registering structure hook for: Job.RerunIntervals
# Registering structure hook for: Folder.When.RuleBasedCalendars
# Registering structure hook for: JobAzureDatabricks
# Registering structure hook for: ConnectionProfileAzureMachineLearning
# Registering structure hook for: BusinessParameter.Characters.Alphanumeric
# Registering structure hook for: ConnectionProfileKubernetes
# Registering structure hook for: JobAwsSageMaker
# Registering structure hook for: ConnectionProfileTableau
# Registering structure hook for: ResourcePools.PeriodicDays
# Registering structure hook for: ConnectionProfileAzureLogicApps
# Registering structure hook for: ConnectionProfileAstronomer
# Registering structure hook for: CalendarRuleBasedCalendar.When.ConfirmationCalendars
# Registering structure hook for: JobGCPBatch
# Registering structure hook for: JobWebServicesREST
# Registering structure hook for: FileTransfer.PostCommandDest
# Registering structure hook for: JobTandemCommand
# Registering structure hook for: JobOS400ExternalJob
# Registering structure hook for: ConnectionProfileAwsCloudFormation
# Registering structure hook for: Job.When.ConfirmationCalendars
# Registering structure hook for: Folder.DocumentationFile
# Registering structure hook for: JobSAPBWProcessChain
# Registering structure hook for: JobTalendOAuth
# Registering structure hook for: JobZOS.MustEnd
# Registering structure hook for: JobAwsAppRunner
# Registering structure hook for: JobHadoopHive
# Registering structure hook for: ConnectionProfileKubernetes.WebServiceAuthenticationAws.AuthMethodIAMRole
# Registering structure hook for: SiteStandardPossibleValue
# Registering structure hook for: ResourcePools.DatesList
# Registering structure hook for: ConnectionProfileAwsStepFunctions
# Registering structure hook for: ActionSetToOK
# Registering structure hook for: IfBaseFolder
# Registering structure hook for: JobTerraform
# Registering structure hook for: ConnectionProfileMicrosoftPowerBISP
# Registering structure hook for: NotifyLateCyclicSubmit
# Registering structure hook for: IfOutput
# Registering structure hook for: JobOS400FullScriptFile.EmbeddedScriptFileLocation
# Registering structure hook for: EndpointDestFtps
# Registering structure hook for: JobDatabaseSQLScript
# Registering structure hook for: BusinessField
# Registering structure hook for: ActionCaptureOutput.ForwardBy
# Registering structure hook for: JobGCPDataprep
# Registering structure hook for: ConnectionProfileDatabaseOracleServiceName
# Registering structure hook for: ConnectionProfileApacheAirflow
# Registering structure hook for: JobAwsGlueDataBrew
# Registering structure hook for: SiteStandardRestrictionEnum
# Registering structure hook for: JobVMwarePowerShutdown
# Registering structure hook for: BusinessParameter.Characters
# Registering structure hook for: ConnectionProfileFileTransferAzureAdUserPass
# Registering structure hook for: ConditionIn
# Registering structure hook for: CalendarRuleBased.When.ConfirmationCalendars
# Registering structure hook for: JobTandemExternalProcess.ExternalProcessId
# Registering structure hook for: ConnectionProfileAzureVM
# Registering structure hook for: FileTransfer.PreCommandDest
# Registering structure hook for: JobAwsDynamoDB
# Registering structure hook for: JobIBMDataStage
# Registering structure hook for: ConnectionProfileAwsAppFlow
# Registering structure hook for: ConnectionProfileOCIDataFlow
# Registering structure hook for: JobScript
# Registering structure hook for: ConnectionProfileAWS
# Registering structure hook for: Variable
# Registering structure hook for: ActionRemedy
# Registering structure hook for: IfJobOutputNotFound
# Registering structure hook for: IfVariableValue
# Registering structure hook for: JobAwsSNS
# Registering structure hook for: EndpointSrc
# Registering structure hook for: ConnectionProfileKubernetes.WebServiceAuthenticationAws
# Registering structure hook for: EndpointDestFtp
# Registering structure hook for: JobVMwareSnapshot
# Registering structure hook for: JobAwsMainframeModernization
# Registering structure hook for: JobTableau
# Registering structure hook for: AddEvents
# Registering structure hook for: ConnectionProfileKubernetes.WebServiceAuthenticationBasic
# Registering structure hook for: JobSAP
# Registering structure hook for: CalendarKey
# Registering structure hook for: ConnectionProfileAwsRedshift
# Registering structure hook for: ActionNotify
# Registering structure hook for: IfVariableValue.RangeVariableValue
# Registering structure hook for: JobOS400FullProgram
# Registering structure hook for: JobAWSBatch.DependsOn
# Registering structure hook for: CalendarFields
# Registering structure hook for: ConnectionProfileAzureServiceBus
# Registering structure hook for: ConnectionProfileDatabaseMSSql
# Registering structure hook for: JobSAPR3COPY.PostJobAction
# Registering structure hook for: IfZOSNumberOfFailures
# Registering structure hook for: JobVMwareConfiguration
# Registering structure hook for: ConnectionProfileVeritasNetBackup
# Registering structure hook for: JobAWSLambda
# Registering structure hook for: JobWebServices
# Registering structure hook for: ConnectionProfileDatabaseOracle
# Registering structure hook for: ConnectionProfileAzureFunctions
# Registering structure hook for: ConnectionProfileGCPBatch
# Registering structure hook for: JobOS400
# Registering structure hook for: HostMapping
# Registering structure hook for: JobTandemExternalProcess.ExternalCPUPIN
# Registering structure hook for: InternalRule.Characters.Alphanumeric
# Registering structure hook for: RbcDetails
# Registering structure hook for: JobSAPDataArchivingWrite
# Registering structure hook for: IfZOS
# Registering structure hook for: JobOS400FullExternalJob
# Registering structure hook for: ConnectionProfileGCPDataflow
# Registering structure hook for: NotifyDoesNotEnd
# Registering structure hook for: ConnectionProfileDatabaseSybase
# Registering structure hook for: ResourceLock
# Registering structure hook for: InternalRule.Include
# Registering structure hook for: CalendarKeyPeriodic
# Registering structure hook for: JobSAPR3SapProfile
# Registering structure hook for: JobSAPR3COPY.DetectSpawnedJob
# Registering structure hook for: ConnectionProfileFileTransferFTP
# Registering structure hook for: JobHadoopSqoop
# Registering structure hook for: NotifyRerun
# Registering structure hook for: ConnectionProfileDatabase
# Registering structure hook for: JobGCPFunctions
# Registering structure hook for: EventDelete
# Registering structure hook for: ConnectionProfileAlteryxTrifacta
# Registering structure hook for: JobAutomationAnywhere
# Registering structure hook for: ConnectionProfileHadoop.Hive
# Registering structure hook for: JobDatabaseEmbeddedQuery
# Registering structure hook for: ConnectionProfileCircleCI
# Registering structure hook for: JobDatabricks
# Registering structure hook for: ConnectionProfileFileTransferAzureManagedIdentity
# Registering structure hook for: Job.RerunLimit
# Registering structure hook for: IfZOSAnyProgramStep
# Registering structure hook for: ConnectionProfileInformatica
# Registering structure hook for: JobOS400FullSubSystem
# Registering structure hook for: ConnectionProfileWebServicesREST.WebServiceAuthenticationAws.AuthMethodIAMRole
# Registering structure hook for: WaitForEvents
# Registering structure hook for: InternalRule.Exclude
# Registering structure hook for: ConnectionProfileFileTransferS3Compatible
# Registering structure hook for: FileTransfer.FileWatcherOptions
# Registering structure hook for: JobSAPR3CREATE.DetectSpawnedJob
# Registering structure hook for: ConnectionProfileAirflowGoogleComposer
# Registering structure hook for: EndpointSrcFtps
# Registering structure hook for: WorkloadPolicy.Filter
# Registering structure hook for: JobMicrosoftPowerBISP
# Registering structure hook for: JobMessagingFreeText
# Registering structure hook for: JobOS400FullVirtualTerminal.EmbeddedScriptFileLocation
# Registering structure hook for: ConnectionProfileAzureSynapse
# Registering structure hook for: Date
# Registering structure hook for: InternalRule.Characters
# Registering structure hook for: JobAwsAthena
# Registering structure hook for: JobAwsDataPipeline
# Registering structure hook for: InternalRule
# Registering structure hook for: JobAwsStepFunctions
# Registering structure hook for: JobSAPR3SapProfileActivate.ProfileInformation
# Registering structure hook for: JobVMwareSnapshotRemove
# Registering structure hook for: ConnectionProfileTalendDataManagement
# Registering structure hook for: Job.DocumentationFile
# Registering structure hook for: ActionRerun
# Registering structure hook for: ConnectionProfileFileTransferAzureSharedAccessSignature
# Registering structure hook for: ItemInfo
# Registering structure hook for: FolderJobBase
# Registering structure hook for: ConnectionProfilePeopleSoft
# Registering structure hook for: Folder
# Registering structure hook for: JobOEBS.RequestSet
# Registering structure hook for: JobSAPR3CREATE.SpoolListRecipient
# Registering structure hook for: JobNetBackup
# Registering structure hook for: JobAwsSQS
# Registering structure hook for: Time
# Registering structure hook for: Condition
# Registering structure hook for: ConnectionProfileDatabaseJDBC
# Registering structure hook for: JobVMwareSnapshotRevertToCurrent
# Registering structure hook for: ConnectionProfileGCPFunctions
# Registering structure hook for: IfZOSEveryProgramStep
# Registering structure hook for: JobSAPR3TriggerSapEvent
# Registering structure hook for: ConnectionProfileAzureResourceManager
# Registering structure hook for: ConnectionProfileWebServicesREST.WebServiceAuthenticationOauth2
# Registering structure hook for: JobAirbyte
# Registering structure hook for: SimpleFolder
# Registering structure hook for: Job.DocumentationUrl
# Registering structure hook for: SiteStandardRestriction
# Registering structure hook for: ConnectionProfileAwsGlue
# Registering structure hook for: JobSAPR3SapProfileDeactivate.ProfileInformation
# Registering structure hook for: Folder.RerunLimit
# Registering structure hook for: JobGCPVM
# Registering structure hook for: ConnectionProfileMicroFocusLinux
# Registering structure hook for: Endpoint
# Registering structure hook for: Job.Rerun
# Registering structure hook for: IfZOSJOBRCCodes
# Registering structure hook for: JobSAPR3PredefinedSapJob.PostJobAction
# Registering structure hook for: ConnectionProfileAwsDataPipeline
# Registering structure hook for: JobHadoopHDFSFileWatcher
# Registering structure hook for: ConnectionProfileMicrosoftPowerBI
# Registering structure hook for: JobKubernetes.WsRestBody
# Registering structure hook for: JobVMwarePowerReboot
# Registering structure hook for: ResourcePools.Time
# Registering structure hook for: ActionControlMAnalyzerRule
# Registering structure hook for: IfZOSSpecificProgramStep
# Registering structure hook for: JobAwsEC2
# Registering structure hook for: InternalRule.Characters.Any
# Registering structure hook for: JobSAPR3WatchSapEvent
# Registering structure hook for: JobAWSStepFunction
# Registering structure hook for: ResourcePools.RangeDates
# Registering structure hook for: JobBoomiAtomsphere
# Registering structure hook for: JobDatabaseStoredProcedure
# Registering structure hook for: ConnectionProfileAwsQuickSight
# Registering structure hook for: ActionRestart
# Registering structure hook for: ConnectionProfileNetBackup
# Registering structure hook for: JobSAPR3CREATE.PostJobAction
# Registering structure hook for: JobSAPR3BatchInputSession.Pattern
# Registering structure hook for: Package
# Registering structure hook for: IfZOSOutputPattern
# Registering structure hook for: FileTransfer
# Registering structure hook for: ConnectionProfileAwsDynamoDB
# Registering structure hook for: JobTag
# Registering structure hook for: JobHadoopTajo
# Registering structure hook for: ConnectionProfileOCIVM
# Registering structure hook for: RunningJobs.PeriodicDays
# Registering structure hook for: ActionSetToNotOK
# Registering structure hook for: ConnectionProfileCommunicationSuite
# Registering structure hook for: ConnectionProfileFileTransferAS2.EncryptMessageParameters
# Registering structure hook for: ConnectionProfileHadoop.Sqoop
# Registering structure hook for: ConnectionProfileAutomationAnywhere
# Registering structure hook for: NotifyNotOK
# Registering structure hook for: JobVMwarePower
# Registering structure hook for: ResourcePools.WeekDaysRange
# Registering structure hook for: IfZOSSpecificRangeName
# Registering structure hook for: JobSAPDataArchivingWrite.Variant
# Registering structure hook for: WorkloadPolicy
# Registering structure hook for: ConnectionProfileGCPCloudRun
# Registering structure hook for: ConnectionProfileVMwareByBroadcom
# Registering structure hook for: JobAzureBatchAccount.Wallclock
# Registering structure hook for: ResourcePools.SpecificTime
# Registering structure hook for: JobHadoopTajoInputFile
# Registering structure hook for: JobOCIVM
# Registering structure hook for: JobFileWatcherCreate
# Registering structure hook for: JobSAPR3PredefinedSapJob.DetectSpawnedJob
# Registering structure hook for: Year
# Registering structure hook for: JobJenkins
# Registering structure hook for: JobApacheAirflow
# Registering structure hook for: JobHadoopOozie
# Registering structure hook for: JobVMwareByBroadcom
# Registering structure hook for: ConnectionProfileAnsibleAWX
# Registering structure hook for: JobInformatica
# Registering structure hook for: EndpointSrcLocal
# Registering structure hook for: ConnectionProfileFileTransferAS2.RequestReceiptParameters
# Registering structure hook for: ConnectionProfileFileTransferS3Amazon
# Registering structure hook for: JobGCPBigQuery
# Registering structure hook for: JobSAPDataArchivingDelete
# Registering structure hook for: ExtractRule
# Registering structure hook for: FileTransfer.PreCommandSrc
# Registering structure hook for: JobSAPDataArchivingWrite.Validations
# Registering structure hook for: ResourcePools.RangeDatesWithTimes
# Registering structure hook for: JobDatabaseMSSQLAgentJob
# Registering structure hook for: RunningJobs.RangeDates
# Registering structure hook for: ConnectionProfileFileTransferGroup
# Registering structure hook for: JobOEBS.SingleRequest
# Registering structure hook for: JobAzureFunctions
# Registering structure hook for: IfCompletionStatus
# Registering structure hook for: ActionStopCyclicRun
# Registering structure hook for: JobAWSBatch
# Registering structure hook for: RunningJobs.Time
# Registering structure hook for: JobOS400Program
# Registering structure hook for: JobOCIDataIntegration
# ...
# Registering job type (via instance): Job:OS400:Full -> JobOS400Full
# Registering job type (via instance): Job:OS400:Full:ExternalJob -> JobOS400FullExternalJob
# Registering job type (via instance): Job:OS400:Full:ExternalSubSystem -> JobOS400FullExternalSubSystem
# Registering job type (via instance): Job:OS400:Full:MultipleCommands -> JobOS400FullMultipleCommands
# Registering job type (via instance): Job:OS400:Full:Program -> JobOS400FullProgram
# Registering job type (via instance): Job:OS400:Full:RestrictedStateAction -> JobOS400FullRestrictedStateAction
# Registering job type (via instance): Job:OS400:Full:ScriptFile -> JobOS400FullScriptFile
# Registering job type (via instance): Job:OS400:Full:VirtualTerminal -> JobOS400FullVirtualTerminal
# Registering job type (via instance): Job:OS400:MultipleCommands -> JobOS400MultipleCommands
# Registering job type (via instance): Job:OS400:VirtualTerminal -> JobOS400VirtualTerminal
# Registering job type (via instance): Job:PagerDuty -> JobPagerDuty
# Registering job type (via instance): Job:PeopleSoft -> JobPeopleSoft
# Registering job type (via instance): Job:Qlik Cloud -> JobQlikCloud
# Registering job type (via instance): Job:RabbitMQ -> JobRabbitMQ
# Registering job type (via instance): Job:SAP -> JobSAP
# Registering job type (via instance): Job:SAP:BW -> JobSAPBW
# Registering job type (via instance): Job:SAP:BW:InfoPackage -> JobSAPBWInfoPackage
# Registering job type (via instance): Job:SAP:BW:ProcessChain -> JobSAPBWProcessChain
# Registering job type (via instance): Job:SAP:DataArchiving -> JobSAPDataArchiving
# Registering job type (via instance): Job:SAP:R3 -> JobSAPR3
# Registering job type (via instance): Job:SAP:R3:BatchInputSession -> JobSAPR3BatchInputSession
# Registering job type (via instance): Job:SAP:R3:COPY -> JobSAPR3COPY
# Registering job type (via instance): Job:SAP:R3:CREATE -> JobSAPR3CREATE
# Registering job type (via instance): Job:SAP:R3:MonitorSapJob -> JobSAPR3MonitorSapJob
# Registering job type (via instance): Job:SAP:R3:PredefinedSapJob -> JobSAPR3PredefinedSapJob
# Registering job type (via instance): Job:SAP:R3:SapProfile -> JobSAPR3SapProfile
# Registering job type (via instance): Job:SAP:R3:SapProfile:Activate -> JobSAPR3SapProfileActivate
# Registering job type (via instance): Job:SAP:R3:SapProfile:Deactivate -> JobSAPR3SapProfileDeactivate
# Registering job type (via instance): Job:Snowflake -> JobSnowflake
# Registering job type (via instance): Job:Snowflake IdP -> JobSnowflakeIdP
# Registering job type (via instance): Job:Tableau -> JobTableau
# Registering job type (via instance): Job:Talend Data Management -> JobTalendDataManagement
# Registering job type (via instance): Job:Talend OAuth -> JobTalendOAuth
# Registering job type (via instance): Job:Terraform -> JobTerraform
# Registering job type (via instance): Job:UI Path -> JobUIPath
# Registering job type (via instance): Job:VMware By Broadcom -> JobVMwareByBroadcom
# Registering job type (via instance): Job:Veritas NetBackup -> JobVeritasNetBackup
# Registering job type (via instance): Job:WebServices -> JobWebServices
# Registering job type (via instance): Job:Web Services REST -> JobWebServicesREST
# Registering job type (via instance): Job:Web Services SOAP -> JobWebServicesSOAP
# Registering job type (via instance): Job:zOS -> JobZOS
# Registering job type (via instance): Job:zOS:InStreamJCL -> JobZOSInStreamJCL
# Registering job type (via instance): Job:zOS:Member -> JobZOSMember
# Registering job type (via instance): Job:AWS -> JobAWS
# Registering job type (via instance): Job:AWS:StepFunction -> JobAWSStepFunction
# Registering job type (via instance): Job:Azure -> JobAzure
# Registering job type (via instance): Job:Database -> JobDatabase
# Registering job type (via instance): Job:Database:SQLScript -> JobDatabaseSQLScript
# Registering job type (via instance): Job:Dummy -> JobDummy
# Registering job type (via instance): Job:FileTransfer -> JobFileTransfer
# Registering job type (via instance): Job:Hadoop -> JobHadoop
# Registering job type (via instance): Job:Hadoop:HDFSCommands -> JobHadoopHDFSCommands
# Registering job type (via instance): Job:Hadoop:HDFSFileWatcher -> JobHadoopHDFSFileWatcher
# Registering job type (via instance): Job:Hadoop:Oozie -> JobHadoopOozie
# Registering job type (via instance): Job:Hadoop:Spark -> JobHadoopSpark
# Registering job type (via instance): Job:Hadoop:Sqoop -> JobHadoopSqoop
# Registering job type (via instance): Job:Hadoop:Tajo -> JobHadoopTajo
# Registering job type (via instance): Job:Messaging -> JobMessaging
# Registering job type (via instance): Job:Messaging:FreeText -> JobMessagingFreeText
# Registering job type (via instance): Job:Messaging:PreDefined -> JobMessagingPreDefined
# Registering job type (via instance): Job:Messaging:WaitForReply -> JobMessagingWaitForReply
# Registering job type (via instance): Job:OS400 -> JobOS400
# Registering job type (via instance): Job:OS400:ExternalJob -> JobOS400ExternalJob
# Registering job type (via instance): Job:OS400:ExternalSubSystem -> JobOS400ExternalSubSystem
# Registering job type (via instance): Job:OS400:Full -> JobOS400Full
# Registering job type (via instance): Job:OS400:Full:ExternalJob -> JobOS400FullExternalJob
# Registering job type (via instance): Job:OS400:Full:ExternalSubSystem -> JobOS400FullExternalSubSystem
# Registering job type (via instance): Job:OS400:Full:MultipleCommands -> JobOS400FullMultipleCommands
# Registering job type (via instance): Job:OS400:Full:Program -> JobOS400FullProgram
# Registering job type (via instance): Job:OS400:Full:RestrictedStateAction -> JobOS400FullRestrictedStateAction
# Registering job type (via instance): Job:OS400:Full:ScriptFile -> JobOS400FullScriptFile
# Registering job type (via instance): Job:OS400:Full:VirtualTerminal -> JobOS400FullVirtualTerminal
# Registering job type (via instance): Job:OS400:MultipleCommands -> JobOS400MultipleCommands
# Registering job type (via instance): Job:OS400:VirtualTerminal -> JobOS400VirtualTerminal
# Registering job type (via instance): Job:PeopleSoft -> JobPeopleSoft
# Registering job type (via instance): Job:SAP -> JobSAP
# Registering job type (via instance): Job:SAP:BW -> JobSAPBW
# Registering job type (via instance): Job:SAP:BW:InfoPackage -> JobSAPBWInfoPackage
# Registering job type (via instance): Job:SAP:BW:ProcessChain -> JobSAPBWProcessChain
# Registering job type (via instance): Job:SAP:DataArchiving -> JobSAPDataArchiving
# Registering job type (via instance): Job:SAP:R3 -> JobSAPR3
# Registering job type (via instance): Job:SAP:R3:BatchInputSession -> JobSAPR3BatchInputSession
# Registering job type (via instance): Job:SAP:R3:COPY -> JobSAPR3COPY
# Registering job type (via instance): Job:SAP:R3:CREATE -> JobSAPR3CREATE
# Registering job type (via instance): Job:SAP:R3:MonitorSapJob -> JobSAPR3MonitorSapJob
# Registering job type (via instance): Job:SAP:R3:PredefinedSapJob -> JobSAPR3PredefinedSapJob
# Registering job type (via instance): Job:SAP:R3:SapProfile -> JobSAPR3SapProfile
# Registering job type (via instance): Job:SAP:R3:SapProfile:Activate -> JobSAPR3SapProfileActivate
# Registering job type (via instance): Job:SAP:R3:SapProfile:Deactivate -> JobSAPR3SapProfileDeactivate
# Registering job type (via instance): Job:WebServices -> JobWebServices
# Registering job type (via instance): Job:zOS -> JobZOS
# Registering job type (via instance): Job:zOS:InStreamJCL -> JobZOSInStreamJCL
# Registering job type (via instance): Job:zOS:Member -> JobZOSMember
# Registering job type (via instance): Job:Airbyte -> JobAirbyte
# Registering job type (via instance): Job:Alteryx Trifacta -> JobAlteryxTrifacta
# Registering job type (via instance): Job:Ansible AWX -> JobAnsibleAWX
# Registering job type (via instance): Job:Apache Airflow -> JobApacheAirflow
# Registering job type (via instance): Job:Apache NiFi -> JobApacheNiFi
# Registering job type (via instance): Job:Astronomer -> JobAstronomer
# Registering job type (via instance): Job:Automation Anywhere -> JobAutomationAnywhere
# Registering job type (via instance): Job:AWS AppFlow -> JobAwsAppFlow
# Registering job type (via instance): Job:AWS App Runner -> JobAwsAppRunner
# Registering job type (via instance): Job:AWS Athena -> JobAwsAthena
# Registering job type (via instance): Job:AWS Backup -> JobAwsBackup
# Registering job type (via instance): Job:AWS Batch -> JobAwsBatch
# Registering job type (via instance): Job:AWS CloudFormation -> JobAwsCloudFormation
# Registering job type (via instance): Job:AWS Data Pipeline -> JobAwsDataPipeline
# Registering job type (via instance): Job:AWS DataSync -> JobAwsDataSync
# Registering job type (via instance): Job:AWS DynamoDB -> JobAwsDynamoDB
# Registering job type (via instance): Job:AWS EC2 -> JobAwsEC2
# Registering job type (via instance): Job:AWS ECS -> JobAwsECS
# Registering job type (via instance): Job:AWS EMR -> JobAwsEMR
# Registering job type (via instance): Job:AWS Glue -> JobAwsGlue
# Registering job type (via instance): Job:AWS Glue DataBrew -> JobAwsGlueDataBrew
# Registering job type (via instance): Job:AWS Lambda -> JobAwsLambda
# Registering job type (via instance): Job:AWS MWAA -> JobAwsMWAA
# Registering job type (via instance): Job:AWS Mainframe Modernization -> JobAwsMainframeModernization
# Registering job type (via instance): Job:AWS QuickSight -> JobAwsQuickSight
# Registering job type (via instance): Job:AWS Redshift -> JobAwsRedshift
# Registering job type (via instance): Job:AWS SNS -> JobAwsSNS
# Registering job type (via instance): Job:AWS SQS -> JobAwsSQS
# Registering job type (via instance): Job:AWS SageMaker -> JobAwsSageMaker
# Registering job type (via instance): Job:AWS Step Functions -> JobAwsStepFunctions
# Registering job type (via instance): Job:Azure Backup -> JobAzureBackup
# Registering job type (via instance): Job:Azure Batch Accounts -> JobAzureBatchAccounts
# Registering job type (via instance): Job:Azure Data Factory -> JobAzureDataFactory
# Registering job type (via instance): Job:Azure Databricks -> JobAzureDatabricks
# Registering job type (via instance): Job:Azure DevOps -> JobAzureDevOps
# Registering job type (via instance): Job:Azure Functions -> JobAzureFunctions
# Registering job type (via instance): Job:Azure HDInsight -> JobAzureHDInsight
# Registering job type (via instance): Job:Azure Logic Apps -> JobAzureLogicApps
# Registering job type (via instance): Job:Azure Machine Learning -> JobAzureMachineLearning
# Registering job type (via instance): Job:Azure Resource Manager -> JobAzureResourceManager
# Registering job type (via instance): Job:Azure Service Bus -> JobAzureServiceBus
# Registering job type (via instance): Job:Azure Synapse -> JobAzureSynapse
# Registering job type (via instance): Job:Azure VM -> JobAzureVM
# Registering job type (via instance): Job:Boomi Atomsphere -> JobBoomiAtomsphere
# Registering job type (via instance): Job:CircleCI -> JobCircleCI
# Registering job type (via instance): Job:Communication Suite -> JobCommunicationSuite
# Registering job type (via instance): Job:DBT -> JobDBT
# Registering job type (via instance): Job:Databricks -> JobDatabricks
# Registering job type (via instance): Job:GCP Batch -> JobGCPBatch
# Registering job type (via instance): Job:GCP BigQuery -> JobGCPBigQuery
# Registering job type (via instance): Job:GCP Cloud Run -> JobGCPCloudRun
# Registering job type (via instance): Job:GCP Composer -> JobGCPComposer
# Registering job type (via instance): Job:GCP Data Fusion -> JobGCPDataFusion
# Registering job type (via instance): Job:GCP Dataflow -> JobGCPDataflow
# Registering job type (via instance): Job:GCP Dataplex -> JobGCPDataplex
# Registering job type (via instance): Job:GCP Dataprep -> JobGCPDataprep
# Registering job type (via instance): Job:GCP Dataproc -> JobGCPDataproc
# Registering job type (via instance): Job:GCP Deployment Manager -> JobGCPDeploymentManager
# Registering job type (via instance): Job:GCP Functions -> JobGCPFunctions
# Registering job type (via instance): Job:GCP VM -> JobGCPVM
# Registering job type (via instance): Job:GCP Workflows -> JobGCPWorkflows
# Registering job type (via instance): Job:IBM DataStage Linux -> JobIBMDataStageLinux
# Registering job type (via instance): Job:IBM DataStage Windows -> JobIBMDataStageWindows
# Registering job type (via instance): Job:Informatica CS -> JobInformaticaCS
# Registering job type (via instance): Job:Jenkins -> JobJenkins
# Registering job type (via instance): Job:Kubernetes -> JobKubernetes
# Registering job type (via instance): Job:Micro Focus Linux -> JobMicroFocusLinux
# Registering job type (via instance): Job:Micro Focus Windows -> JobMicroFocusWindows
# Registering job type (via instance): Job:Microsoft Power BI -> JobMicrosoftPowerBI
# Registering job type (via instance): Job:Microsoft Power BI SP -> JobMicrosoftPowerBISP
# Registering job type (via instance): Job:NetBackup -> JobNetBackup
# Registering job type (via instance): Job:OCI Data Flow -> JobOCIDataFlow
# Registering job type (via instance): Job:OCI Data Integration -> JobOCIDataIntegration
# Registering job type (via instance): Job:OCI Data Science -> JobOCIDataScience
# Registering job type (via instance): Job:OCI VM -> JobOCIVM
# Registering job type (via instance): Job:PagerDuty -> JobPagerDuty
# Registering job type (via instance): Job:Qlik Cloud -> JobQlikCloud
# Registering job type (via instance): Job:RabbitMQ -> JobRabbitMQ
# Registering job type (via instance): Job:Snowflake -> JobSnowflake
# Registering job type (via instance): Job:Snowflake IdP -> JobSnowflakeIdP
# Registering job type (via instance): Job:Tableau -> JobTableau
# Registering job type (via instance): Job:Talend Data Management -> JobTalendDataManagement
# Registering job type (via instance): Job:Talend OAuth -> JobTalendOAuth
# Registering job type (via instance): Job:Terraform -> JobTerraform
# Registering job type (via instance): Job:UI Path -> JobUIPath
# Registering job type (via instance): Job:VMware By Broadcom -> JobVMwareByBroadcom
# Registering job type (via instance): Job:Veritas NetBackup -> JobVeritasNetBackup
# Registering job type (via instance): Job:Web Services REST -> JobWebServicesREST
# Registering job type (via instance): Job:Web Services SOAP -> JobWebServicesSOAP
# <ctm_python_client.core.workflow.Workflow object at 0x000001DD104F9B80>
# === Folder_Sanity_1 - Job 0 (databricksLoad) ===
# {
#     "Type": "Job:Command",
#     "RunAs": "workbench",
#     "eventsToWaitFor": {
#         "Type": "WaitForEvents",
#         "Events": [
#             {
#                 "Event": "e1"
#             },
#             {
#                 "Event": "e2"
#             },
#             {
#                 "Event": "e3",
#                 "Date": "AnyDate"
#             }
#         ]
#     },
#     "eventsToAdd": {
#         "Type": "AddEvents",
#         "Events": [
#             {
#                 "Event": "e2",
#                 "Date": "NoDate"
#             },
#             {
#                 "Event": "e3",
#                 "Date": "NoDate"
#             }
#         ]
#     },
#     "eventsToDelete": {
#         "Type": "DeleteEvents",
#         "Events": [
#             {
#                 "Event": "e5",
#                 "Date": "NextOrderDate"
#             },
#             {
#                 "Event": "e4",
#                 "Date": "NextOrderDate"
#             }
#         ]
#     },
#     "Command": "ls -lt"
# }
# {
#     "Type": "Job",
#     "RunAs": "workbench",
#     "eventsToWaitFor": {
#         "Type": "WaitForEvents",
#         "Events": [
#             {
#                 "Event": "e1"
#             },
#             {
#                 "Event": "e2"
#             },
#             {
#                 "Event": "e3",
#                 "Date": "AnyDate"
#             }
#         ]
#     },
#     "eventsToAdd": {
#         "Type": "AddEvents",
#         "Events": [
#             {
#                 "Event": "e2",
#                 "Date": "NoDate"
#             },
#             {
#                 "Event": "e3",
#                 "Date": "NoDate"
#             }
#         ]
#     },
#     "eventsToDelete": {
#         "Type": "DeleteEvents",
#         "Events": [
#             {
#                 "Event": "e5",
#                 "Date": "NextOrderDate"
#             },
#             {
#                 "Event": "e4",
#                 "Date": "NextOrderDate"
#             }
#         ]
#     }
# }
